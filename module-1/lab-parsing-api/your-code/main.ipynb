# %%
# your code here
import json
import requests as r
import pandas as pd
import feedparser

# %%
response = r.get("https://bloomberg-market-and-financial-news.p.rapidapi.com/stories/list?template=CURRENCY&id=usdjpy",
  headers={
    "X-RapidAPI-Host": "bloomberg-market-and-financial-news.p.rapidapi.com",
    "X-RapidAPI-Key": "d6538c1f36msh2c5eead427feae3p145149jsnafc0ad989377"
  }
)

# %%
json = response.json()

# %%
json.keys()
# Out:
# dict_keys(['stories', 'title'])

# %%
json['stories'][0]['title']
# Out:
# 'An Anomaly in Rupee Forwards Has Traders Search for RBI Hand'

# %%
json['title']
# Out:
# 'Currencies'

# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
import json
import requests as r
import pandas as pd

# %%
page = '168'

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=' + page + '&sort=sale'
uf = r.urlopen(url)

# %%
response = uf.read().decode('utf-8')
type(response)
# Out:
# str

# %%
results = json.loads(response)
results
# Out:
# {'total_count': 21450,
#  'pagination': {'page_count': 256, 'current_page': 3, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'NI112O00Q-Q21',
#    'name': 'AIR VAPORMAX PLUS - Baskets basses - black/white',
#    'price': {'original': '209,95\xa0€',
#     'promotional': '168,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5'],
#    'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q21',
#    'media': [{'path': 'NI/11/2O/00/QQ/21/NI112O00Q-Q21@11.1.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'},
#     {'path': 'NI/11/2O/00/QQ/21/NI112O00Q-Q21@18.jpg',
#      'packet_shot': False,
#      'role': 'HOVER'}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI112O00Q-Q21',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q21',
#      'media': [{'path': 'NI/11/2O/00/QQ/21/NI112O00Q-Q21@11.1.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - black/white',
#      'sizes': ['38.5',
#       '39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '168,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'HOT DROP',
#        'tracking_value': 'mu_sneaker_releases'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'NI112O00Q-Q16',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q16',
#      'media': [{'path': 'NI/11/2O/00/QQ/16/NI112O00Q-Q16@8.2.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - black/dark grey/aluminum/space purple',
#      'sizes': ['40', '40.5', '41', '42.5', '44', '44.5', '45', '46'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'HOT DROP',
#        'tracking_value': 'mu_sneaker_releases'}]},
#     {'sku': 'NI112O00Q-A11',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-a11',
#      'media': [{'path': 'NI/11/2O/00/QA/11/NI112O00Q-A11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - white/pure platinum',
#      'sizes': ['40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI112O00Q-Q18',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q18',
#      'media': [{'path': 'NI/11/2O/00/QQ/18/NI112O00Q-Q18@8.2.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - black/reflect silver/volt',
#      'sizes': ['40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'HOT DROP',
#        'tracking_value': 'mu_sneaker_releases'}]},
#     {'sku': 'NI112O00Q-Q23',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q23',
#      'media': [{'path': 'NI/11/2O/00/QQ/23/NI112O00Q-Q23@2.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - white/mtlc silver/wolf grey',
#      'sizes': ['38.5',
#       '39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}]},
#     {'sku': 'NI112O00Q-Q19',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q19',
#      'media': [{'path': 'NI/11/2O/00/QQ/19/NI112O00Q-Q19@8.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - black/aluminium',
#      'sizes': ['40', '40.5', '42', '42.5', '48.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'HOT DROP',
#        'tracking_value': 'mu_sneaker_releases'}]},
#     {'sku': 'NI112O00Q-Q22',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q22',
#      'media': [{'path': 'NI/11/2O/00/QQ/22/NI112O00Q-Q22@5.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - obsidian/laser orange/indigo storm/deep royal blue',
#      'sizes': ['40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI112O00Q-Q17',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-q17',
#      'media': [{'path': 'NI/11/2O/00/QQ/17/NI112O00Q-Q17@4.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - wolf grey/black/dark grey',
#      'sizes': ['42',
#       '42.5',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI112O00Q-Q11',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-blackdark-grey-ni112o00q-q11',
#      'media': [{'path': 'NI/11/2O/00/QQ/11/NI112O00Q-Q11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - black/dark grey',
#      'sizes': ['42.5', '44', '44.5', '45', '45.5', '46', '47', '47.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI112O00Q-L11',
#      'url_key': 'nike-sportswear-air-vapormax-plus-baskets-basses-ni112o00q-l11',
#      'media': [{'path': 'NI/11/2O/00/QL/11/NI112O00Q-L11@11.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'AIR VAPORMAX PLUS - Baskets basses - spirit teal/black/green abyss',
#      'sizes': ['38.5',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5'],
#      'price': {'original': '209,95\xa0€',
#       'promotional': '209,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'HOT DROP',
#        'tracking_value': 'mu_sneaker_releases'}]}],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'PI912M02R-O11',
#    'name': 'Derbies & Richelieus - cognac',
#    'price': {'original': '59,99\xa0€',
#     'promotional': '36,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['41', '42', '43', '44', '45', '46'],
#    'url_key': 'pier-one-derbies-cognac-pi912m02r-o11',
#    'media': [{'path': 'PI/91/2M/02/RO/11/PI912M02R-O11@9.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [{'sku': 'PI912M02R-O11',
#      'url_key': 'pier-one-derbies-cognac-pi912m02r-o11',
#      'media': [{'path': 'PI/91/2M/02/RO/11/PI912M02R-O11@9.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Derbies & Richelieus - cognac',
#      'sizes': ['41', '42', '43', '44', '45', '46'],
#      'price': {'original': '59,99\xa0€',
#       'promotional': '36,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'PI912M02R-Q11',
#      'url_key': 'pier-one-derbies-black-pi912m02r-q11',
#      'media': [{'path': 'PI/91/2M/02/RQ/11/PI912M02R-Q11@9.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Derbies & Richelieus - black',
#      'sizes': ['40', '41', '42', '43', '44', '45', '46'],
#      'price': {'original': '59,99\xa0€',
#       'promotional': '30,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'BB182D00D-Q11',
#    'name': 'PEARLEYE - Short de bain - black',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '40,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'boss-pearleye-short-de-bain-bb182d00d-q11',
#    'media': [{'path': 'BB/18/2D/00/DQ/11/BB182D00D-Q11@10.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'},
#     {'path': 'BB/18/2D/00/DQ/11/BB182D00D-Q11@9.jpg',
#      'packet_shot': False,
#      'role': 'HOVER'}],
#    'brand_name': 'BOSS',
#    'is_premium': True,
#    'family_articles': [{'sku': 'BB182D00D-Q11',
#      'url_key': 'boss-pearleye-short-de-bain-bb182d00d-q11',
#      'media': [{'path': 'BB/18/2D/00/DQ/11/BB182D00D-Q11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'PEARLEYE - Short de bain - black',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '40,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'BB182D00D-K12',
#      'url_key': 'boss-pearleye-short-de-bain-bb182d00d-k12',
#      'media': [{'path': 'BB/18/2D/00/DK/12/BB182D00D-K12@10.1.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'PEARLEYE - Short de bain - navy',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'BB182D00D-A11',
#      'url_key': 'boss-pearleye-short-de-bain-white-bb182d00d-a11',
#      'media': [{'path': 'BB/18/2D/00/DA/11/BB182D00D-A11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'PEARLEYE - Short de bain - white',
#      'sizes': ['S', 'L', 'XL', 'XXL'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'BB182D00D-K17',
#      'url_key': 'boss-pearleye-short-de-bain-bb182d00d-k17',
#      'media': [{'path': 'BB/18/2D/00/DK/17/BB182D00D-K17@6.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'PEARLEYE - Short de bain - bright blue',
#      'sizes': ['M', 'L', 'XL', 'XXL'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'beach_wear'},
#   {'sku': 'PI912M047-K11',
#    'name': 'Chaussures à lacets - dark blue',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '42,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['40', '41', '43', '44', '45', '46'],
#    'url_key': 'pier-one-chaussures-a-lacets-dark-blue-pi912m047-k11',
#    'media': [{'path': 'PI/91/2M/04/7K/11/PI912M047-K11@9.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [{'sku': 'PI912M047-K11',
#      'url_key': 'pier-one-chaussures-a-lacets-dark-blue-pi912m047-k11',
#      'media': [{'path': 'PI/91/2M/04/7K/11/PI912M047-K11@9.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Chaussures à lacets - dark blue',
#      'sizes': ['40', '41', '43', '44', '45', '46'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '42,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'MA322O06H-K11',
#    'name': 'BASIC SINGLE - T-shirt imprimé - deep ocean',
#    'price': {'original': '21,95\xa0€',
#     'promotional': '17,56\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'marc-opolo-t-shirt-imprime-deep-ocean-ma322o06h-k11',
#    'media': [{'path': 'MA/32/2O/06/HK/11/MA322O06H-K11@10.jpg',
#      'packet_shot': False,
#      'role': 'DEFAULT'},
#     {'path': 'MA/32/2O/06/HK/11/MA322O06H-K11@11.jpg',
#      'packet_shot': False,
#      'role': 'HOVER'}],
#    'brand_name': "Marc O'Polo",
#    'is_premium': False,
#    'family_articles': [{'sku': 'MA322O06H-K11',
#      'url_key': 'marc-opolo-t-shirt-imprime-deep-ocean-ma322o06h-k11',
#      'media': [{'path': 'MA/32/2O/06/HK/11/MA322O06H-K11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'BASIC SINGLE - T-shirt imprimé - deep ocean',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '21,95\xa0€',
#       'promotional': '17,56\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'MA322O06H-A11',
#      'url_key': 'marc-opolo-basic-single-t-shirt-imprime-ma322o06h-a11',
#      'media': [{'path': 'MA/32/2O/06/HA/11/MA322O06H-A11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'BASIC SINGLE - T-shirt imprimé - white',
#      'sizes': ['XL', 'XXL'],
#      'price': {'original': '21,95\xa0€',
#       'promotional': '21,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'MA322O06H-C11',
#      'url_key': 'marc-opolo-basic-single-t-shirt-imprime-ma322o06h-c11',
#      'media': [{'path': 'MA/32/2O/06/HC/11/MA322O06H-C11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'BASIC SINGLE - T-shirt imprimé - gray pinstripe',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '21,95\xa0€',
#       'promotional': '21,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'MA322O06H-Q11',
#      'url_key': 'marc-opolo-basic-single-t-shirt-imprime-ma322o06h-q11',
#      'media': [{'path': 'MA/32/2O/06/HQ/11/MA322O06H-Q11@8.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'BASIC SINGLE - T-shirt imprimé - black',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '21,95\xa0€',
#       'promotional': '21,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'JA222G0OG-K11',
#    'name': 'JJIGLENN JJICON - Jean slim - blue denim',
#    'price': {'original': '79,99\xa0€',
#     'promotional': '52,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['26x34',
#     '27x30',
#     '27x32',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '31x34',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '36x32',
#     '36x34',
#     '36x36'],
#    'url_key': 'jack-and-jones-jjiglenn-jjicon-jean-slim-blue-denim-ja222g0og-k11',
#    'media': [{'path': 'JA/22/2G/0O/GK/11/JA222G0OG-K11@10.jpg',
#      'packet_shot': False,
#      'role': 'DEFAULT'},
#     {'path': 'JA/22/2G/0O/GK/11/JA222G0OG-K11@11.jpg',
#      'packet_shot': False,
#      'role': 'HOVER'}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JA222G0OG-K11',
#      'url_key': 'jack-and-jones-jjiglenn-jjicon-jean-slim-blue-denim-ja222g0og-k11',
#      'media': [{'path': 'JA/22/2G/0O/GK/11/JA222G0OG-K11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'JJIGLENN JJICON - Jean slim - blue denim',
#      'sizes': ['26x34',
#       '27x30',
#       '27x32',
#       '28x30',
#       '28x32',
#       '28x34',
#       '29x30',
#       '29x32',
#       '30x30',
#       '30x32',
#       '30x34',
#       '31x30',
#       '31x32',
#       '31x34',
#       '32x30',
#       '32x32',
#       '32x34',
#       '32x36',
#       '33x30',
#       '33x32',
#       '33x34',
#       '33x36',
#       '34x30',
#       '34x32',
#       '34x34',
#       '34x36',
#       '36x32',
#       '36x34',
#       '36x36'],
#      'price': {'original': '79,99\xa0€',
#       'promotional': '52,00\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -35%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'ST312C00K-B11',
#    'name': 'KLIQUE - Mocassins - tan',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '55,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['40', '41', '42', '43', '44', '46'],
#    'url_key': 'steve-madden-klique-mocassins-st312c00k-b11',
#    'media': [{'path': 'ST/31/2C/00/KB/11/ST312C00K-B11@10.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'}],
#    'brand_name': 'Steve Madden',
#    'is_premium': False,
#    'family_articles': [{'sku': 'ST312C00K-B11',
#      'url_key': 'steve-madden-klique-mocassins-st312c00k-b11',
#      'media': [{'path': 'ST/31/2C/00/KB/11/ST312C00K-B11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'KLIQUE - Mocassins - tan',
#      'sizes': ['40', '41', '42', '43', '44', '46'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '55,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'ST312C00K-K11',
#      'url_key': 'steve-madden-klique-mocassins-navy-st312c00k-k11',
#      'media': [{'path': 'ST/31/2C/00/KK/11/ST312C00K-K11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'KLIQUE - Mocassins - navy',
#      'sizes': ['40', '43', '45', '46'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '87,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'NI112A028-A11',
#    'name': "AIR MAX '95 - Baskets basses - white/black",
#    'price': {'original': '169,95\xa0€',
#     'promotional': '153,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-air-max-95-baskets-basses-ni112a028-a11',
#    'media': [{'path': 'NI/11/2A/02/8A/11/NI112A028-A11@13.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI112A028-A11',
#      'url_key': 'nike-sportswear-air-max-95-baskets-basses-ni112a028-a11',
#      'media': [{'path': 'NI/11/2A/02/8A/11/NI112A028-A11@13.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': "AIR MAX '95 - Baskets basses - white/black",
#      'sizes': ['38.5',
#       '39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5',
#       '49.5'],
#      'price': {'original': '169,95\xa0€',
#       'promotional': '153,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'NI112A028-Q12',
#      'url_key': 'nike-sportswear-air-max-95-baskets-basses-ni112a028-q12',
#      'media': [{'path': 'NI/11/2A/02/8Q/12/NI112A028-Q12@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': "AIR MAX '95 - Baskets basses - black/anthracite",
#      'sizes': ['38.5',
#       '39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5'],
#      'price': {'original': '169,95\xa0€',
#       'promotional': '153,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': '4CCiJY5IR8a',
#      'url_key': '/outfits/4CCiJY5IR8a',
#      'media': [{'path': '5ad007623cac4ab4b7bb300536992d49/df579a696e8a4321b5660667927501fb.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'men',
#      'creator': {'id': 'ad7935e1-0c9b-4cf6-b737-ad51a773c126',
#       'name': 'richykoll',
#       'media': [{'path': '6b5511f5c0fb4cc698516e9d91018b05/039825bcefc74404af14a68fb2c87bd6.jpeg',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'JA222O2BT-Q11'},
#       {'id': 'NI122E059-Q11'},
#       {'id': 'NI112A028-A11'}]}]},
#   {'sku': 'TO112B02R-A11',
#    'name': 'Baskets basses - white',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '90,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['41', '42', '43', '44', '45', '46'],
#    'url_key': 'tommy-hilfiger-harrington-baskets-basses-white-to112b02r-a11',
#    'media': [{'path': 'TO/11/2B/02/RA/11/TO112B02R-A11@12.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TO112B02R-A11',
#      'url_key': 'tommy-hilfiger-harrington-baskets-basses-white-to112b02r-a11',
#      'media': [{'path': 'TO/11/2B/02/RA/11/TO112B02R-A11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Baskets basses - white',
#      'sizes': ['41', '42', '43', '44', '45', '46'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '90,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'TO112B02R-K11',
#      'url_key': 'tommy-hilfiger-harrington-baskets-basses-to112b02r-k11',
#      'media': [{'path': 'TO/11/2B/02/RK/11/TO112B02R-K11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Baskets basses - blue',
#      'sizes': ['41', '42', '43', '44', '45'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '69,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'TO112B02R-Q11',
#      'url_key': 'tommy-hilfiger-harrington-baskets-basses-to112b02r-q11',
#      'media': [{'path': 'TO/11/2B/02/RQ/11/TO112B02R-Q11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Baskets basses - black',
#      'sizes': ['41', '42', '43', '44', '45'],
#      'price': {'original': '94,95\xa0€',
#       'promotional': '76,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'N1242A1BZ-Q11',
#    'name': 'REVOLUTION 4 EU - Chaussures de running neutres - black/white/antracite',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '37,46\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-performance-nike-revolution-4-chaussures-de-running-neutres-n1242a1bz-q11',
#    'media': [{'path': 'N1/24/2A/1B/ZQ/11/N1242A1BZ-Q11@14.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242A1BZ-Q11',
#      'url_key': 'nike-performance-nike-revolution-4-chaussures-de-running-neutres-n1242a1bz-q11',
#      'media': [{'path': 'N1/24/2A/1B/ZQ/11/N1242A1BZ-Q11@14.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - black/white/antracite',
#      'sizes': ['38.5',
#       '39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5',
#       '49.5'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '37,46\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -25%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'N1242A1BZ-C13',
#      'url_key': 'nike-performance-revolution-4-eu-chaussures-de-running-neutres-n1242a1bz-c13',
#      'media': [{'path': 'N1/24/2A/1B/ZC/13/N1242A1BZ-C13@4.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - thunder grey/team crimson/gunsmoke/amarillo/black/white',
#      'sizes': ['38.5', '47'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}],
#      'amount': '208 g'},
#     {'sku': 'N1242A1BZ-K13',
#      'url_key': 'nike-performance-revolution-4-eu-chaussures-de-running-neutres-n1242a1bz-k13',
#      'media': [{'path': 'N1/24/2A/1B/ZK/13/N1242A1BZ-K13@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - uomu blu',
#      'sizes': ['38.5',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44.5',
#       '45.5',
#       '47',
#       '47.5'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '232 g'},
#     {'sku': 'N1242A1BZ-C11',
#      'url_key': 'nike-performance-revolution-4-eu-chaussures-de-running-neutres-n1242a1bz-c11',
#      'media': [{'path': 'N1/24/2A/1B/ZC/11/N1242A1BZ-C11@4.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - wolf grey/lime blast/cool grey/white',
#      'sizes': ['42'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '204 g'},
#     {'sku': 'N1242A1BZ-Q13',
#      'url_key': 'nike-performance-nike-revolution-4-chaussures-de-running-neutres-n1242a1bz-q13',
#      'media': [{'path': 'N1/24/2A/1B/ZQ/13/N1242A1BZ-Q13@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - black/black',
#      'sizes': ['38.5',
#       '40.5',
#       '41',
#       '42',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5',
#       '49.5'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'N1242A1BZ-G12',
#      'url_key': 'nike-performance-revolution-4-eu-chaussures-de-running-neutres-n1242a1bz-g12',
#      'media': [{'path': 'N1/24/2A/1B/ZG/12/N1242A1BZ-G12@8.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - university red/wolf grey/red orbit/white',
#      'sizes': ['42.5', '43', '44', '44.5', '45.5'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '236 g'},
#     {'sku': 'N1242A1BZ-A11',
#      'url_key': 'nike-performance-nike-revolution-4-chaussures-de-running-neutres-n1242a1bz-a11',
#      'media': [{'path': 'N1/24/2A/1B/ZA/11/N1242A1BZ-A11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - white/pure platinum',
#      'sizes': ['38.5',
#       '39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '49.5'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'N1242A1BZ-C14',
#      'url_key': 'nike-performance-revolution-4-eu-chaussures-de-running-neutres-n1242a1bz-c14',
#      'media': [{'path': 'N1/24/2A/1B/ZC/14/N1242A1BZ-C14@8.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'REVOLUTION 4 EU - Chaussures de running neutres - dark grey/black/cool grey/white',
#      'sizes': ['40.5'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '49,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}],
#      'amount': '318 g'}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'GO112B00V-C11',
#    'name': 'COMET - Baskets basses - grey/khaki',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '48,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['40', '41', '42', '43', '45'],
#    'url_key': 'gola-cma516-baskets-basses-go112b00v-c11',
#    'media': [{'path': 'GO/11/2B/00/VC/11/GO112B00V-C11@7.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'}],
#    'brand_name': 'Gola',
#    'is_premium': False,
#    'family_articles': [{'sku': 'GO112B00V-C11',
#      'url_key': 'gola-cma516-baskets-basses-go112b00v-c11',
#      'media': [{'path': 'GO/11/2B/00/VC/11/GO112B00V-C11@7.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'COMET - Baskets basses - grey/khaki',
#      'sizes': ['40', '41', '42', '43', '45'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '48,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'GO112B00V-K12',
#      'url_key': 'gola-cma516-baskets-basses-go112b00v-k12',
#      'media': [{'path': 'GO/11/2B/00/VK/12/GO112B00V-K12@11.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'COMET - Baskets basses - navy/white',
#      'sizes': ['41', '42', '43'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '59,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'GO112B00V-A11',
#      'url_key': 'gola-cma516-baskets-basses-whitenavyred-go112b00v-a11',
#      'media': [{'path': 'GO/11/2B/00/VA/11/GO112B00V-A11@12.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'COMET - Baskets basses - white/navy/red',
#      'sizes': ['40', '41', '42', '43', '44', '45', '46'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '42,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'GO112B00V-H11',
#      'url_key': 'gola-cma516-baskets-basses-go112b00v-h11',
#      'media': [{'path': 'GO/11/2B/00/VH/11/GO112B00V-H11@8.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'COMET - Baskets basses - sun/navy',
#      'sizes': ['42', '43', '44', '45', '46'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '48,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'GO112B00V-N11',
#      'url_key': 'gola-cma516-baskets-basses-go112b00v-n11',
#      'media': [{'path': 'GO/11/2B/00/VN/11/GO112B00V-N11@8.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'COMET - Baskets basses - khaki/black',
#      'sizes': ['40', '41', '42'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '48,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'PU122E03A-Q11',
#    'name': 'FERRARI - Pantalon de survêtement -  black',
#    'price': {'original': '80,00\xa0€',
#     'promotional': '40,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'puma-pantalon-de-survetement-black-pu122e03a-q11',
#    'media': [{'path': 'PU/12/2E/03/AQ/11/PU122E03A-Q11@13.jpg',
#      'packet_shot': True,
#      'role': 'DEFAULT'},
#     {'path': 'PU/12/2E/03/AQ/11/PU122E03A-Q11@12.jpg',
#      'packet_shot': False,
#      'role': 'HOVER'}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [{'sku': 'PU122E03A-Q11',
#      'url_key': 'puma-pantalon-de-survetement-black-pu122e03a-q11',
#      'media': [{'path': 'PU/12/2E/03/AQ/11/PU122E03A-Q11@13.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'FERRARI - Pantalon de survêtement -  black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '80,00\xa0€',
#       'promotional': '40,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'PU122E03A-C11',
#      'url_key': 'puma-pantalon-de-survetement-grey-pu122e03a-c11',
#      'media': [{'path': 'PU/12/2E/03/AC/11/PU122E03A-C11@13.jpg',
#        'packet_shot': False,
#        'role': 'FAMILY'}],
#      'name': 'FERRARI - Pantalon de survêtement - medium gray heather',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '80,00\xa0€',
#       'promotional': '40,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'NI122T01O-K11',
#    'name': 'Veste légère - night maroon/wolf grey/sail',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '56,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'nike-sportswear-veste-legere-night-maroonwolf-greysail-ni122t01o-k11',
#    'media': [{'path': 'NI/12/2T/01/OK/11/NI122T01O-K11@9.jpg',
#      'packet_shot': False,
#      'role': 'DEFAULT'},
#     {'path': 'NI/12/2T/01/OK/11/NI122T01O-K11@6.jpg',
#      'packet_shot': False,
#      'role': 'HOVER'}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI122T01O-K11',
#      'url_key': 'nike-sportswear-veste-legere-night-maroonwolf-greysail-ni122t01o-k11',
#      'media': [{'path': 'NI/12/2T/01/OK/11/NI122T01O-K11@7.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Veste légère - night maroon/wolf grey/sail',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '56,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'NI122T01O-Q12',
#      'url_key': 'nike-sportswear-veste-legere-black-ni122t01o-q12',
#      'media': [{'path': 'NI/12/2T/01/OQ/12/NI122T01O-Q12@8.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Veste légère - black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI122T01O-C11',
#      'url_key': 'nike-sportswear-veste-legere-aviator-greynightshadewhite-ni122t01o-c11',
#      'media': [{'path': 'NI/12/2T/01/OC/11/NI122T01O-C11@10.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Veste légère - aviator grey/nightshade/white',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI122T01O-A12',
#      'url_key': 'nike-sportswear-veste-legere-light-creamorange-peelnightshade-ni122t01o-a12',
#      'media': [{'path': 'NI/12/2T/01/OA/12/NI122T01O-A12@9.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Veste légère - light cream/orange peel/nightshade',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI122T01O-A13',
#      'url_key': 'nike-sportswear-veste-legere-summit-white-ni122t01o-a13',
#      'media': [{'path': 'NI/12/2T/01/OA/13/NI122T01O-A13@7.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Veste légère - summit white',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '80,00\xa0€',
#       'promotional': '80,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}]},
#     {'sku': 'NI122T01O-Q11',
#      'url_key': 'nike-sportswear-veste-legere-blackspirit-tealspace-purpleactive-fuchsia-ni122t01o-q11',
#      'media': [{'path': 'NI/12/2T/01/OQ/11/NI122T01O-Q11@4.jpg',
#        'packet_shot': True,
#        'role': 'FAMILY'}],
#      'name': 'Veste légère - black/spirit teal/space purple/active fuchsia',
#      'sizes': ['M', 'XL'],
# ...
#     {'key': '47B', 'label': "'47", 'is_family': False},
#     {'key': '111', 'label': '11 DEGREES', 'is_family': False},
#     {'key': 'L19', 'label': '120% Lino', 'is_family': False},
#     {'key': '190', 'label': '1904', 'is_family': False},
#     {'key': '7F1', 'label': '7 for all mankind', 'is_family': False},
#     {'key': '880', 'label': '8848 Altitude', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4,
#     'max': 1600,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'lengths',
#    'label': 'Longueur',
#    'url_key': 'length',
#    'kind': 'values',
#    'values': [{'key': '26', 'label': '26'},
#     {'key': '28', 'label': '28'},
#     {'key': '29', 'label': '29'},
#     {'key': '3/4', 'label': '3/4'},
#     {'key': '30', 'label': '30'},
#     {'key': '31', 'label': '31'},
#     {'key': '32', 'label': '32'},
#     {'key': '33', 'label': '33'},
#     {'key': '34', 'label': '34'},
#     {'key': '36', 'label': '36'},
#     {'key': '38', 'label': '38'},
#     {'key': '40', 'label': '40'},
#     {'key': '7/8', 'label': '7/8'},
#     {'key': 'courte', 'label': 'courte'},
#     {'key': 'extra courte', 'label': 'extra courte'},
#     {'key': 'extra longue', 'label': 'extra longue'},
#     {'key': "Jusqu'aux genoux", 'label': "Jusqu'aux genoux"},
#     {'key': 'longue', 'label': 'longue'},
#     {'key': 'Longueur mi-cuisse', 'label': 'Longueur mi-cuisse'},
#     {'key': 'Longueur midi', 'label': 'Longueur midi'},
#     {'key': 'Moyenne', 'label': 'Moyenne'},
#     {'key': 'normale', 'label': 'normale'},
#     {'key': 'socquettes', 'label': 'socquettes'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'BUSINESS', 'label': 'business'},
#     {'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'sales',
#    'label': 'Promotion',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les Promos'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'OTHER', 'label': 'Autres matières'},
#     {'key': 'CASHMERE', 'label': 'Cachemire'},
#     {'key': 'CAOUTCHOUC', 'label': 'Caoutchouc'},
#     {'key': 'COTTON', 'label': 'Coton'},
#     {'key': 'CROCHETED', 'label': 'Crocheté'},
#     {'key': 'LEATHER', 'label': 'Cuir'},
#     {'key': 'CORD', 'label': 'Côtelé'},
#     {'key': 'DENIM', 'label': 'Denim'},
#     {'key': 'LACE', 'label': 'Dentelle'},
#     {'key': 'HARDSHELL', 'label': 'Hardshell'},
#     {'key': 'IMITATION_LEATHER', 'label': 'Imitation cuir'},
#     {'key': 'JERSEY', 'label': 'Jersey'},
#     {'key': 'WOOL', 'label': 'Laine'},
#     {'key': 'LINEN', 'label': 'Lin'},
#     {'key': 'MESH', 'label': 'Mesh'},
#     {'key': 'FLEECE', 'label': 'Polaire'},
#     {'key': 'POLYESTER', 'label': 'Polyester'},
#     {'key': 'SOFTSHELL', 'label': 'Softshell'},
#     {'key': 'SILK', 'label': 'Soie'},
#     {'key': 'RIB', 'label': 'Strié'},
#     {'key': 'SWEAT', 'label': 'Sweat'},
#     {'key': 'SYNTHETIC', 'label': 'Synthétique'},
#     {'key': 'TEXTILE', 'label': 'Textile'},
#     {'key': 'BRAIDED', 'label': 'tressé'},
#     {'key': 'VISCOSE', 'label': 'Viscose'}]},
#   {'key': 'campaigns',
#    'label': 'Campaigns',
#    'url_key': 'camp',
#    'kind': 'single_value',
#    'values': [{'key': 'exclusivites_zalando_2018',
#      'label': 'EXCLUSIVITÉS ZALANDO'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}]}],
#  'total_article_count': 21453,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promotions',
#    'id': '9191',
#    'url_key': 'promo-homme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-homme/',
#    'children': [{'label': 'Vêtements',
#      'id': '9205',
#      'url_key': 'promo-mode-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-homme/',
#      'children': [],
#      'article_count': 14877},
#     {'label': 'Chaussures',
#      'id': '9192',
#      'url_key': 'promo-chaussures-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-homme/',
#      'children': [],
#      'article_count': 5238},
#     {'label': 'Sport',
#      'id': '13690',
#      'url_key': 'promo-sport-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-homme/',
#      'children': [],
#      'article_count': 2616},
#     {'label': 'Accessoires',
#      'id': '9222',
#      'url_key': 'promo-accessoires-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-homme/',
#      'children': [],
#      'article_count': 1195},
#     {'label': 'Luxe',
#      'id': '13825',
#      'url_key': 'promo-luxe-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-homme/',
#      'children': [],
#      'article_count': 1029},
#     {'label': 'Beauté',
#      'id': '13865',
#      'url_key': 'beaute-homme-soins-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-homme-soins-promo/',
#      'children': [],
#      'article_count': 70}],
#    'article_count': 21453}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Homme',
#      'url_key': 'homme',
#      'full_url': '/homme/'},
#     {'label': 'Promotions',
#      'url_key': 'promo-homme',
#      'full_url': '/promo-homme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-homme',
#       'url_key': 'promo-homme',
#       'label': 'Promotions',
#       'seo_label': 'Promotions homme',
#       'reset_url': '/',
#       'id': '9191'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-homme/',
#   'reset_url': '/promo-homme/',
#   'app_url': '?urlKey=promo-homme&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-homme',
#     'url_key': 'promo-homme',
#     'label': 'Promotions',
#     'seo_label': 'Promotions homme',
#     'reset_url': '/',
#     'id': '9191'}]},
#  'selectedFilters': {'categories': ['promo-homme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'inlineNavbar': False,
#   'showInGridFilter': None,
#   'emphasizedBreadcrumbEnabled': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': False},
#  'searchDialog': None,
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'search-dialog': [9, 19],
#   'search-dialog-mobile': [8, 15],
#   'search-dialog-fullwidth': [12, 25],
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': True,
#  'seoText': None,
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/7c593fe9-967e-4cea-a888-409102591c19/23f0cf83-27a8-43c4-b1f1-c314a2d32478/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c&timeUnit=null&timeUnitCount=null&uuid=415a7943-de16-4f14-bd39-f4a1706fdb0d&bid=null&requestId=240ae9f1-31e3-45dd-b5ff-cef90a0703e5&s=0DEA67F5D4D48B34ACE3EFA49B2E44F7'],
#    'images': [{'aspect_ratio': '75:64',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/5de847eb-7b9c-45c6-a1df-b57f56720303.jpg',
#      'image_width': 750},
#     {'aspect_ratio': '16:3',
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/fd1c7732-dde1-4de3-aa1e-8f10f4d64869.jpg',
#      'image_width': 3200}],
#    'creative_id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c',
#    'campaign_id': '7c593fe9-967e-4cea-a888-409102591c19',
#    'campaign_name': 'TCT FR SS19 Prepare Your Basket Men_FR_FR_MAN_June_24_25_CatAd_C_000000',
#    'text_fields': {'cta': "Je prends de l'avance !",
#     'sales_template': 'Voucher',
#     'title': 'Sélectionnez vos articles maintenant et retrouvez-les soldés dans votre panier mercredi !',
#     'type': 'sales',
#     'byline': 'J-2 : PRÉPAREZ VOTRE PANIER'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'TCT FR SS19 Prepare Your Basket Men_FR_FR_MAN_June_24_25_CatAd_C_000000',
#       'brand_code': '-1',
#       'billing_method': 'CPV',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': 'E5gTXv+LGPaq1Hs0',
#       'price': 0.00816204614929822,
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'undefined',
#       'request_id': '240ae9f1-31e3-45dd-b5ff-cef90a0703e5',
#       'campaign_id': '7c593fe9-967e-4cea-a888-409102591c19',
#       'creative_id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c',
#      'name': 'Sélectionnez vos articles maintenant et retrouvez-les soldés dans votre panier mercredi !',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 Prepare Your Basket Men_FR_FR_MAN_June_24_25_CatAd_C_000000',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'E5gTXv+LGPaq1Hs0',
#        'price': 0.00816204614929822,
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '240ae9f1-31e3-45dd-b5ff-cef90a0703e5',
#        'campaign_id': '7c593fe9-967e-4cea-a888-409102591c19',
#        'creative_id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c',
#      'name': 'Sélectionnez vos articles maintenant et retrouvez-les soldés dans votre panier mercredi !',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 Prepare Your Basket Men_FR_FR_MAN_June_24_25_CatAd_C_000000',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'E5gTXv+LGPaq1Hs0',
#        'price': 0.00816204614929822,
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '240ae9f1-31e3-45dd-b5ff-cef90a0703e5',
#        'campaign_id': '7c593fe9-967e-4cea-a888-409102591c19',
#        'creative_id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/7c593fe9-967e-4cea-a888-409102591c19/23f0cf83-27a8-43c4-b1f1-c314a2d32478/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c&timeUnit=null&timeUnitCount=null&uuid=f8807474-c9e3-4de1-87a4-b0a84577cf5d&bid=8&requestId=240ae9f1-31e3-45dd-b5ff-cef90a0703e5&s=76219C39A7CB333F229C5D1891B0B36D'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'E5gTXv+LGPaq1Hs0',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': '7c593fe9-967e-4cea-a888-409102591c19',
#      'creative_id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c',
#      'campaign_name': 'TCT FR SS19 Prepare Your Basket Men_FR_FR_MAN_June_24_25_CatAd_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'TCT FR SS19 Prepare Your Basket Men_FR_FR_MAN_June_24_25_CatAd_C_000000',
#      'brand_code': '-1',
#      'billing_method': 'CPV',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': 'E5gTXv+LGPaq1Hs0',
#      'price': 0.00816204614929822,
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'undefined',
#      'request_id': '240ae9f1-31e3-45dd-b5ff-cef90a0703e5',
#      'campaign_id': '7c593fe9-967e-4cea-a888-409102591c19',
#      'creative_id': 'cfe57d4f-cfe3-46a4-b1d8-15f7e7283a8c'}},
#    'click_url': 'https://www.zalando.fr/homme/?season_name=printemps-été'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'styleYourKicks': None,
#  'sizeOnboardingDialog': None}

# %%
type(results)
# Out:
# dict

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
df = pd.DataFrame(results)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-2935a30b64a7> in <module>
#       1 # your code here
# ----> 2 df = pd.DataFrame(results)
#       3 df.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in extract_index(data)
#    7400             lengths = list(set(raw_lengths))
#    7401             if len(lengths) > 1:
# -> 7402                 raise ValueError('arrays must all be same length')
#    7403
#    7404             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
