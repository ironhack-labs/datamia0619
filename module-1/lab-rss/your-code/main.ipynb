# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
reddit1 = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
reddit1.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
reddit1.feed
# Out:
# {'title': "All - O'Reilly Media",
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#   'value': "All - O'Reilly Media"},
#  'id': 'https://www.oreilly.com',
#  'guidislink': True,
#  'link': 'https://www.oreilly.com',
#  'updated': '2019-06-26T15:34:19Z',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=26, tm_hour=15, tm_min=34, tm_sec=19, tm_wday=2, tm_yday=177, tm_isdst=0),
#  'subtitle': 'All of our Ideas and Learning material from all of our topics.',
#  'subtitle_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#   'value': 'All of our Ideas and Learning material from all of our topics.'},
#  'links': [{'href': 'https://www.oreilly.com',
#    'rel': 'alternate',
#    'type': 'text/html'},
#   {'rel': 'self',
#    'type': 'application/atom+xml',
#    'href': 'http://feeds.feedburner.com/oreilly/radar/atom'},
#   {'rel': 'hub',
#    'href': 'http://pubsubhubbub.appspot.com/',
#    'type': 'text/html'}],
#  'authors': [{'name': "O'Reilly Media"}],
#  'author_detail': {'name': "O'Reilly Media"},
#  'author': "O'Reilly Media",
#  'feedburner_info': {'uri': 'oreilly/radar/atom'},
#  'geo_lat': '38.393314',
#  'geo_long': '-122.836667',
#  'feedburner_emailserviceid': 'oreilly/radar/atom',
#  'feedburner_feedburnerhostname': 'https://feedburner.google.com'}

# %%
reddit1.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'id', 'guidislink', 'link', 'updated', 'updated_parsed', 'subtitle', 'subtitle_detail', 'links', 'authors', 'author_detail', 'author', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
reddit1.feed.title
# Out:
# "All - O'Reilly Media"

# %%
reddit1.feed.subtitle
# Out:
# 'All of our Ideas and Learning material from all of our topics.'

# %%
reddit1.feed.author
# Out:
# "O'Reilly Media"

# %%
reddit1.feed.link
# Out:
# 'https://www.oreilly.com'

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(reddit1.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
reddit1.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'updated', 'updated_parsed', 'id', 'guidislink', 'link', 'content', 'summary', 'links', 'authors', 'author_detail', 'author', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
lst = [reddit1.entries[i].title for i in range(len(reddit1.entries))]
lst
# Out:
# ['Four short links: 26 June 2019',
#  'AI and machine learning will require retraining your entire organization',
#  'Four short links: 25 June 2019',
#  'Four short links: 24 June 2019',
#  'Four short links: 21 June 2019',
#  'Four short links: 20 June 2019',
#  'Enabling end-to-end machine learning pipelines in real-world applications',
#  'Four short links: 19 June 2019',
#  'What are model governance and model operations?',
#  'Four short links: 18 June 2019',
#  'The quest for high-quality data',
#  'Four short links: 17 June 2019',
#  'Prioritizing technical debt as if time and money mattered',
#  'Choices of scale',
#  'From the trenches with Rebecca Parsons',
#  'Four short links: 14 June 2019',
#  'The cloud native elephant in the room',
#  'Infrastructure first: Because solving complex problems needs more than technology',
#  'How do we heal?',
#  'Cultivating production excellence',
#  'Kubernetes for the impatient',
#  "Highlights from the O'Reilly Software Architecture Conference in San Jose 2019",
#  'Next Architecture',
#  'Architect as storyteller',
#  'Security and deception: Lessons from a professional liar',
#  'Cultivate your personal design heuristics',
#  'Four short links: 13 June 2019',
#  'From puzzles to products',
#  'The SRE I aspire to be',
#  "Highlights from the O'Reilly Velocity Conference in San Jose 2019",
#  'Community projects inform enterprise products',
#  'Scaling teams with technology (or is it the other way around?)',
#  'Channel into the universe of eventually perfect distributed systems',
#  'Four short links: 12 June 2019',
#  'Four short links: 11 June 2019',
#  'AI adoption is being fueled by an improved tool ecosystem',
#  'How to get started with site reliability engineering (SRE)',
#  'Maximizing paper clips',
#  'Four short links: 10 June 2019',
#  'Four short links: 7 June 2019',
#  'Bringing scalable real-time analytics to the enterprise',
#  'Four short links: 6 June 2019',
#  'Four short links: 5 June 2019',
#  'New live online training courses',
#  'Four short links: 4 June 2019',
#  'What’s driving open source software in 2019',
#  'Reduce toil through better alerting',
#  'Four short links: 3 June 2019',
#  'Four short links: 31 May 2019',
#  'Four short links: 30 May 2019',
#  'Four short links: 29 May 2019',
#  'Four short links: 28 May 2019',
#  'Four short links: 27 May 2019',
#  'Four short links: 24 May 2019',
#  'Applications of data science and machine learning in financial services',
#  'Four short links: 23 May 2019',
#  'Four short links: 22 May 2019',
#  'Becoming a machine learning company means investing in foundational technologies',
#  'Four short links: 21 May 2019',
#  'Four short links: 20 May 2019']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
z = 'Four short links:'
count_4 = 0
for title in lst:
    if z in title:
        count_4 += 1
percentage = count_4/len(lst)
print(percentage*100)
# Out:
# 46.666666666666664

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(reddit1.entries)
df.head(10)
# Out:
#                                   author  \
# 0                         Nat Torkington
# 1                             Ben Lorica
# 2                         Nat Torkington
# 3                         Nat Torkington
# 4                         Nat Torkington
# 5                         Nat Torkington
# 6                             Ben Lorica
# 7                         Nat Torkington
# 8  Ben Lorica, Harish Doddi, David Talby
# 9                         Nat Torkington
#
#                                        author_detail  \
# 0                         {'name': 'Nat Torkington'}
# 1                             {'name': 'Ben Lorica'}
# 2                         {'name': 'Nat Torkington'}
# 3                         {'name': 'Nat Torkington'}
# 4                         {'name': 'Nat Torkington'}
# 5                         {'name': 'Nat Torkington'}
# 6                             {'name': 'Ben Lorica'}
# 7                         {'name': 'Nat Torkington'}
# 8  {'name': 'Ben Lorica, Harish Doddi, David Talby'}
# 9                         {'name': 'Nat Torkington'}
#
#                                              authors  \
# 0                       [{'name': 'Nat Torkington'}]
# 1                           [{'name': 'Ben Lorica'}]
# 2                       [{'name': 'Nat Torkington'}]
# 3                       [{'name': 'Nat Torkington'}]
# 4                       [{'name': 'Nat Torkington'}]
# 5                       [{'name': 'Nat Torkington'}]
# 6                           [{'name': 'Ben Lorica'}]
# 7                       [{'name': 'Nat Torkington'}]
# 8  [{'name': 'Ben Lorica, Harish Doddi, David Tal...
# 9                       [{'name': 'Nat Torkington'}]
#
#                                              content  \
# 0  [{'type': 'text/html', 'language': None, 'base...
# 1  [{'type': 'text/html', 'language': None, 'base...
# 2  [{'type': 'text/html', 'language': None, 'base...
# 3  [{'type': 'text/html', 'language': None, 'base...
# 4  [{'type': 'text/html', 'language': None, 'base...
# 5  [{'type': 'text/html', 'language': None, 'base...
# 6  [{'type': 'text/html', 'language': None, 'base...
# 7  [{'type': 'text/html', 'language': None, 'base...
# 8  [{'type': 'text/html', 'language': None, 'base...
# 9  [{'type': 'text/html', 'language': None, 'base...
#
#                                  feedburner_origlink  guidislink  \
# 0  https://www.oreilly.com/ideas/four-short-links...        True
# 1  https://www.oreilly.com/ideas/ai-and-machine-l...        True
# 2  https://www.oreilly.com/ideas/four-short-links...        True
# 3  https://www.oreilly.com/ideas/four-short-links...        True
# 4  https://www.oreilly.com/ideas/four-short-links...        True
# 5  https://www.oreilly.com/ideas/four-short-links...        True
# 6  https://www.oreilly.com/ideas/enabling-end-to-...        True
# 7  https://www.oreilly.com/ideas/four-short-links...        True
# 8  https://www.oreilly.com/ideas/what-are-model-g...        True
# 9  https://www.oreilly.com/ideas/four-short-links...        True
#
#                                                   id  \
# 0  tag:www.oreilly.com,2019-06-26:/ideas/four-sho...
# 1  tag:www.oreilly.com,2019-06-26:/ideas/ai-and-m...
# 2  tag:www.oreilly.com,2019-06-25:/ideas/four-sho...
# 3  tag:www.oreilly.com,2019-06-24:/ideas/four-sho...
# 4  tag:www.oreilly.com,2019-06-21:/ideas/four-sho...
# 5  tag:www.oreilly.com,2019-06-20:/ideas/four-sho...
# 6  tag:www.oreilly.com,2019-06-20:/ideas/enabling...
# 7  tag:www.oreilly.com,2019-06-19:/ideas/four-sho...
# 8  tag:www.oreilly.com,2019-06-19:/ideas/what-are...
# 9  tag:www.oreilly.com,2019-06-18:/ideas/four-sho...
#
#                                                 link  \
# 0  http://feedproxy.google.com/~r/oreilly/radar/a...
# 1  http://feedproxy.google.com/~r/oreilly/radar/a...
# 2  http://feedproxy.google.com/~r/oreilly/radar/a...
# 3  http://feedproxy.google.com/~r/oreilly/radar/a...
# 4  http://feedproxy.google.com/~r/oreilly/radar/a...
# 5  http://feedproxy.google.com/~r/oreilly/radar/a...
# 6  http://feedproxy.google.com/~r/oreilly/radar/a...
# 7  http://feedproxy.google.com/~r/oreilly/radar/a...
# 8  http://feedproxy.google.com/~r/oreilly/radar/a...
# 9  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                links  \
# 0  [{'href': 'http://feedproxy.google.com/~r/orei...
# 1  [{'href': 'http://feedproxy.google.com/~r/orei...
# 2  [{'href': 'http://feedproxy.google.com/~r/orei...
# 3  [{'href': 'http://feedproxy.google.com/~r/orei...
# 4  [{'href': 'http://feedproxy.google.com/~r/orei...
# 5  [{'href': 'http://feedproxy.google.com/~r/orei...
# 6  [{'href': 'http://feedproxy.google.com/~r/orei...
# 7  [{'href': 'http://feedproxy.google.com/~r/orei...
# 8  [{'href': 'http://feedproxy.google.com/~r/orei...
# 9  [{'href': 'http://feedproxy.google.com/~r/orei...
#
#                                              summary  \
# 0  <p><em>Ethics and OKRs, Rewriting Binaries, Di...
# 1  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 2  <p><em>Analog Deep Learning, Low-Trust Interne...
# 3  <p><em>Wacky Timestamps, Computers and Spies, ...
# 4  <p><em>Private Computation, Robot Framework, 3...
# 5  <p><em>Model Governance, Content Moderators, I...
# 6  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 7  <p><em>Voice2Face, DIY Minivac, Cloud Metrics,...
# 8  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 9  <p><em>JavaScript Spreadsheets, Pessimism, Pri...
#
#                                                title  \
# 0                     Four short links: 26 June 2019
# 1  AI and machine learning will require retrainin...
# 2                     Four short links: 25 June 2019
# 3                     Four short links: 24 June 2019
# 4                     Four short links: 21 June 2019
# 5                     Four short links: 20 June 2019
# 6  Enabling end-to-end machine learning pipelines...
# 7                     Four short links: 19 June 2019
# 8    What are model governance and model operations?
# 9                     Four short links: 18 June 2019
#
#                                         title_detail               updated  \
# 0  {'type': 'text/plain', 'language': None, 'base...  2019-06-26T11:15:00Z
# 1  {'type': 'text/plain', 'language': None, 'base...  2019-06-26T11:00:00Z
# 2  {'type': 'text/plain', 'language': None, 'base...  2019-06-25T10:50:00Z
# 3  {'type': 'text/plain', 'language': None, 'base...  2019-06-24T10:45:00Z
# 4  {'type': 'text/plain', 'language': None, 'base...  2019-06-21T10:45:00Z
# 5  {'type': 'text/plain', 'language': None, 'base...  2019-06-20T21:55:00Z
# 6  {'type': 'text/plain', 'language': None, 'base...  2019-06-20T11:50:00Z
# 7  {'type': 'text/plain', 'language': None, 'base...  2019-06-19T11:05:00Z
# 8  {'type': 'text/plain', 'language': None, 'base...  2019-06-19T11:00:00Z
# 9  {'type': 'text/plain', 'language': None, 'base...  2019-06-18T11:50:00Z
#
#                         updated_parsed
# 0  (2019, 6, 26, 11, 15, 0, 2, 177, 0)
# 1   (2019, 6, 26, 11, 0, 0, 2, 177, 0)
# 2  (2019, 6, 25, 10, 50, 0, 1, 176, 0)
# 3  (2019, 6, 24, 10, 45, 0, 0, 175, 0)
# 4  (2019, 6, 21, 10, 45, 0, 4, 172, 0)
# 5  (2019, 6, 20, 21, 55, 0, 3, 171, 0)
# 6  (2019, 6, 20, 11, 50, 0, 3, 171, 0)
# 7   (2019, 6, 19, 11, 5, 0, 2, 170, 0)
# 8   (2019, 6, 19, 11, 0, 0, 2, 170, 0)
# 9  (2019, 6, 18, 11, 50, 0, 1, 169, 0)

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                                    author  entries
# 19                         Nat Torkington       28
# 2                              Ben Lorica        6
# 0                           Adam Tornhill        1
# 14                         Liz Fong-Jones        1
# 25                            Yaniv Aknin        1
# 24     Roger Magoulas, Rachel Roumeliotis        1
# 23                    Rebecca Wirfs-Brock        1
# 22             Rebecca Parsons, Neal Ford        1
# 21                         Nikki McDonald        1
# 20                      Nathaniel Schutta        1
# 18                          Mike Loukides        1
# 17                       Michael Feathers        1
# 16                       Michael Carducci        1
# 15                             Mac Slocum        1
# 13                              Lena Hall        1
# 1                                Alex Qin        1
# 12      Lachlan Evenson, Bridget Kromhout        1
# 11                           Jessica Kerr        1
# 10                              Jenn Webb        1
# 9                  Ihab Ilyas, Ben Lorica        1
# 8                          Everett Harper        1
# 7                        Chris Guzikowski        1
# 6                           Chen Goldberg        1
# 5                        Bridget Kromhout        1
# 4                             Bob Quillin        1
# 3   Ben Lorica, Harish Doddi, David Talby        1
# 26          Štěpán Davidovič, Betsy Beyer        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
title_length = [len(title) for title in lst]
df['title length'] = title_length
df1 = df[['title', 'author', 'title length']].copy()
df1 = df1.sort_values('title length', ascending=False)
df1
# Out:
#                                                 title  \
# 17  Infrastructure first: Because solving complex ...
# 57  Becoming a machine learning company means inve...
# 21  Highlights from the O'Reilly Software Architec...
# 6   Enabling end-to-end machine learning pipelines...
# 1   AI and machine learning will require retrainin...
# 54  Applications of data science and machine learn...
# 32  Channel into the universe of eventually perfec...
# 29  Highlights from the O'Reilly Velocity Conferen...
# 31  Scaling teams with technology (or is it the ot...
# 36  How to get started with site reliability engin...
# 12  Prioritizing technical debt as if time and mon...
# 35  AI adoption is being fueled by an improved too...
# 24  Security and deception: Lessons from a profess...
# 40  Bringing scalable real-time analytics to the e...
# 8     What are model governance and model operations?
# 30      Community projects inform enterprise products
# 45        What’s driving open source software in 2019
# 25          Cultivate your personal design heuristics
# 14             From the trenches with Rebecca Parsons
# 16              The cloud native elephant in the room
# 46                Reduce toil through better alerting
# 19                  Cultivating production excellence
# 43                   New live online training courses
# 10                    The quest for high-quality data
# 33                     Four short links: 12 June 2019
# 38                     Four short links: 10 June 2019
# 34                     Four short links: 11 June 2019
# 0                      Four short links: 26 June 2019
# 4                      Four short links: 21 June 2019
# 9                      Four short links: 18 June 2019
# 26                     Four short links: 13 June 2019
# 5                      Four short links: 20 June 2019
# 2                      Four short links: 25 June 2019
# 7                      Four short links: 19 June 2019
# 15                     Four short links: 14 June 2019
# 3                      Four short links: 24 June 2019
# 11                     Four short links: 17 June 2019
# 49                      Four short links: 30 May 2019
# 50                      Four short links: 29 May 2019
# 51                      Four short links: 28 May 2019
# 44                      Four short links: 4 June 2019
# 52                      Four short links: 27 May 2019
# 48                      Four short links: 31 May 2019
# 55                      Four short links: 23 May 2019
# 56                      Four short links: 22 May 2019
# 58                      Four short links: 21 May 2019
# 53                      Four short links: 24 May 2019
# 59                      Four short links: 20 May 2019
# 47                      Four short links: 3 June 2019
# 42                      Four short links: 5 June 2019
# 41                      Four short links: 6 June 2019
# 39                      Four short links: 7 June 2019
# 20                       Kubernetes for the impatient
# 27                           From puzzles to products
# 23                           Architect as storyteller
# 37                             Maximizing paper clips
# 28                             The SRE I aspire to be
# 22                                  Next Architecture
# 13                                   Choices of scale
# 18                                    How do we heal?
#
#                                    author  title length
# 17                         Everett Harper            81
# 57                             Ben Lorica            80
# 21                              Jenn Webb            78
# 6                              Ben Lorica            73
# 1                              Ben Lorica            72
# 54                             Ben Lorica            71
# 32                              Lena Hall            67
# 29                             Mac Slocum            65
# 31                          Chen Goldberg            62
# 36                         Nikki McDonald            58
# 12                          Adam Tornhill            57
# 35                             Ben Lorica            57
# 24                       Michael Carducci            56
# 40                             Ben Lorica            55
# 8   Ben Lorica, Harish Doddi, David Talby            47
# 30      Lachlan Evenson, Bridget Kromhout            45
# 45     Roger Magoulas, Rachel Roumeliotis            43
# 25                    Rebecca Wirfs-Brock            41
# 14             Rebecca Parsons, Neal Ford            38
# 16                            Bob Quillin            37
# 46          Štěpán Davidovič, Betsy Beyer            35
# 19                         Liz Fong-Jones            33
# 43                                    NaN            32
# 10                 Ihab Ilyas, Ben Lorica            31
# 33                         Nat Torkington            30
# 38                         Nat Torkington            30
# 34                         Nat Torkington            30
# 0                          Nat Torkington            30
# 4                          Nat Torkington            30
# 9                          Nat Torkington            30
# 26                         Nat Torkington            30
# 5                          Nat Torkington            30
# 2                          Nat Torkington            30
# 7                          Nat Torkington            30
# 15                         Nat Torkington            30
# 3                          Nat Torkington            30
# 11                         Nat Torkington            30
# 49                         Nat Torkington            29
# 50                         Nat Torkington            29
# 51                         Nat Torkington            29
# 44                         Nat Torkington            29
# 52                         Nat Torkington            29
# 48                         Nat Torkington            29
# 55                         Nat Torkington            29
# 56                         Nat Torkington            29
# 58                         Nat Torkington            29
# 53                         Nat Torkington            29
# 59                         Nat Torkington            29
# 47                         Nat Torkington            29
# 42                         Nat Torkington            29
# 41                         Nat Torkington            29
# 39                         Nat Torkington            29
# 20                       Bridget Kromhout            28
# 27                           Jessica Kerr            24
# 23                      Nathaniel Schutta            24
# 37                          Mike Loukides            22
# 28                            Yaniv Aknin            22
# 22                       Chris Guzikowski            17
# 13                       Michael Feathers            16
# 18                               Alex Qin            15

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
lst_m_c = [title for title in lst if 'machine learning' in title ]
lst_m_c
# Out:
# ['AI and machine learning will require retraining your entire organization',
#  'Enabling end-to-end machine learning pipelines in real-world applications',
#  'Applications of data science and machine learning in financial services',
#  'Becoming a machine learning company means investing in foundational technologies']
