# %%
import requests
import pandas as pd 
import getpass
import json

# %%
username = 'Gayushka'
token = getpass.getpass(prompt='Token:', stream=None)

# Create a re-usable session object with the user creds in-built
gh_session = requests.Session()
gh_session.auth = (username, token)
# Out:
# Token:········

# %%
token = 'ca9806b4f820cb98404a5dd1899c3420cc0fb7f2'

# %%
url = 'https://api.github.com' + '/repos/ironhack-datalabs/datamia0619/forks'
#'/repos/:owner/:repo/forks'

# %%
request = requests.get(url,auth=gh_session.auth)

# %%
json = request.json()
json
# Out:
# [{'id': 191448721,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTE0NDg3MjE=',
#   'name': 'datamia0619',
#   'full_name': 'Gayushka/datamia0619',
#   'private': False,
#   'owner': {'login': 'Gayushka',
#    'id': 44560318,
#    'node_id': 'MDQ6VXNlcjQ0NTYwMzE4',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/44560318?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gayushka',
#    'html_url': 'https://github.com/Gayushka',
#    'followers_url': 'https://api.github.com/users/Gayushka/followers',
#    'following_url': 'https://api.github.com/users/Gayushka/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Gayushka/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Gayushka/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Gayushka/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Gayushka/orgs',
#    'repos_url': 'https://api.github.com/users/Gayushka/repos',
# ...

# %%
df = pd.DataFrame(json)

# %%
df.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'merges_url',
#        'milestones_url', 'mirror_url', 'name', 'node_id', 'notifications_url',
#        'open_issues', 'open_issues_count', 'owner', 'permissions', 'private',
#        'pulls_url', 'pushed_at', 'releases_url', 'size', 'ssh_url',
# ...

# %%
df = df['forks_url']#, 'languages_url','fork', 'forks', 'forks_count','forks_url']
forks = [i for i in df]

# %%
forks
# Out:
# ['https://api.github.com/repos/Gayushka/datamia0619/forks',
#  'https://api.github.com/repos/NoahBeckerman/datamia0619/forks',
#  'https://api.github.com/repos/gissellec16/datamia0619/forks',
#  'https://api.github.com/repos/regina9/datamia0619/forks',
#  'https://api.github.com/repos/haggarw3/datamia0619/forks',
#  'https://api.github.com/repos/gtxsy/datamia0619/forks',
#  'https://api.github.com/repos/fnau001/datamia0619/forks']

# %%
json[1]['languages_url']
# Out:
# 'https://api.github.com/repos/NoahBeckerman/datamia0619/languages'

# %%
r = requests.get(json[1]['languages_url'],auth=gh_session.auth)

# %%
l = r.json()

# %%
l
# Out:
# {'Jupyter Notebook': 1498270, 'HTML': 498316, 'Python': 20656}

# %%
lst = []
for i in range(len(json)): 
    r = requests.get(json[i]['languages_url'],auth=gh_session.auth)
    lst.append(r.json())

# %%
lst
# Out:
# [{'Jupyter Notebook': 1392824, 'HTML': 498316, 'Python': 20656},
#  {'Jupyter Notebook': 1498270, 'HTML': 498316, 'Python': 20656},
#  {'Jupyter Notebook': 1416355, 'HTML': 498316, 'Python': 20656},
#  {'Jupyter Notebook': 1587852, 'HTML': 498316, 'Python': 20656},
#  {'Jupyter Notebook': 1352185, 'HTML': 498316, 'Python': 20656},
#  {'Jupyter Notebook': 1661583, 'HTML': 498316, 'Python': 20691, 'TSQL': 654},
#  {'Jupyter Notebook': 1352169, 'HTML': 498316, 'Python': 20693}]

# %%
#HURRRRAAYYYYYYYYYYYYYY CHALLENGE 1 DONE

# %%
url = 'https://api.github.com' + '/repos/ironhack-datalabs/datamia0619/commits'

# %%
commits_request = requests.get(url,auth=gh_session.auth)

# %%
commits_json = commits_request.json()

# %%
lst_1 = []
for i in range(len(commits_json)): 
    commits = commits_json[i]['commit']
    lst_1.append(commits)
lst_1
# Out:
# [{'author': {'name': 'Himanshu Aggarwal',
#    'email': 'haggarw3@asu.edu',
#    'date': '2019-06-10T18:45:35Z'},
#   'committer': {'name': 'GitHub',
#    'email': 'noreply@github.com',
#    'date': '2019-06-10T18:45:35Z'},
#   'message': 'Update README.md',
#   'tree': {'sha': 'da48408c9b2541f4285b7843ba6f58c7525cad55',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/datamia0619/git/trees/da48408c9b2541f4285b7843ba6f58c7525cad55'},
#   'url': 'https://api.github.com/repos/ironhack-datalabs/datamia0619/git/commits/3d931cc0519f1b91738a3a29c17771e88599776f',
#   'comment_count': 0,
#   'verification': {'verified': True,
#    'reason': 'valid',
# ...

# %%
#HURRRAYYYYYY CHALLENGE 2 DONE !!

# %%
print('number of commits:' + str(len(lst_1)))
# Out:
# number of commits:30

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476?recursive=1?recursive=1'
#/repos/:owner/:repo/contents/:path
#/repos/:owner/:repo/git/trees/:tree_sha
#/repos/:owner/:repo/git/trees/:tree_sha?recursive=1

# %%
s_request = requests.get(url,auth=gh_session.auth)

# %%
s_request
# Out:
# <Response [200]>

# %%
result = s_request.json()

# %%
result
# Out:
# {'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'tree': [{'path': '.gitignore',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'size': 10,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'},
#   {'path': '15024',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'},
#   {'path': '15024/.0006.scavengerhunt',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'},
# ...

# %%
df = pd.DataFrame(result)
df.head()
# Out:
#                                         sha  \
# 0  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 1  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 2  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 3  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 4  9308ccc8a4c34c5e3a991ee815222a9691c32476
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                                 tree  truncated
# 0  {'path': '.gitignore', 'mode': '100644', 'type...      False
# 1  {'path': '15024', 'mode': '040000', 'type': 't...      False
# 2  {'path': '15024/.0006.scavengerhunt', 'mode': ...      False
# 3  {'path': '15024/40', 'mode': '100644', 'type':...      False
# ...

# %%
path = df['tree']
path.head()
# Out:
# 0    {'path': '.gitignore', 'mode': '100644', 'type...
# 1    {'path': '15024', 'mode': '040000', 'type': 't...
# 2    {'path': '15024/.0006.scavengerhunt', 'mode': ...
# 3    {'path': '15024/40', 'mode': '100644', 'type':...
# 4    {'path': '15024/74', 'mode': '100644', 'type':...
# Name: tree, dtype: object

# %%
path[2]
# Out:
# {'path': '15024/.0006.scavengerhunt',
#  'mode': '100644',
#  'type': 'blob',
#  'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#  'size': 3,
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'}

# %%
path[2]['path']
# Out:
# '15024/.0006.scavengerhunt'

# %%
path_list = []

for dic in path: 
    p = dic['path']
    if 'scavengerhunt' in p:
        path_list.append(p)
        
path_list
# Out:
# ['15024/.0006.scavengerhunt',
#  '15534/.0008.scavengerhunt',
#  '15534/.0012.scavengerhunt',
#  '17020/.0007.scavengerhunt',
#  '30351/.0021.scavengerhunt',
#  '40303/.0022.scavengerhunt',
#  '44639/.0005.scavengerhunt',
#  '45525/.0018.scavengerhunt',
#  '47222/.0016.scavengerhunt',
#  '47222/.0024.scavengerhunt',
#  '47830/.0010.scavengerhunt',
#  '49418/.0014.scavengerhunt',
#  '50896/.0011.scavengerhunt',
#  '55417/.0023.scavengerhunt',
#  '55685/.0020.scavengerhunt',
#  '60224/.0003.scavengerhunt',
#  '68848/.0004.scavengerhunt',
#  '70751/.0019.scavengerhunt',
#  '70985/.0017.scavengerhunt',
#  '88596/.0002.scavengerhunt',
#  '89338/.0013.scavengerhunt',
#  '91701/.0015.scavengerhunt',
#  '97881/.0009.scavengerhunt',
#  '98750/.0001.scavengerhunt']

# %%
slist = sorted(path_list)
slist
# Out:
# ['15024/.0006.scavengerhunt',
#  '15534/.0008.scavengerhunt',
#  '15534/.0012.scavengerhunt',
#  '17020/.0007.scavengerhunt',
#  '30351/.0021.scavengerhunt',
#  '40303/.0022.scavengerhunt',
#  '44639/.0005.scavengerhunt',
#  '45525/.0018.scavengerhunt',
#  '47222/.0016.scavengerhunt',
#  '47222/.0024.scavengerhunt',
#  '47830/.0010.scavengerhunt',
#  '49418/.0014.scavengerhunt',
#  '50896/.0011.scavengerhunt',
#  '55417/.0023.scavengerhunt',
#  '55685/.0020.scavengerhunt',
#  '60224/.0003.scavengerhunt',
#  '68848/.0004.scavengerhunt',
#  '70751/.0019.scavengerhunt',
#  '70985/.0017.scavengerhunt',
#  '88596/.0002.scavengerhunt',
#  '89338/.0013.scavengerhunt',
#  '91701/.0015.scavengerhunt',
#  '97881/.0009.scavengerhunt',
#  '98750/.0001.scavengerhunt']

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt'

# %%
request = requests.get(url,auth=gh_session.auth)

# %%
text = request.json()

# %%
text['content']
# Out:
# 'b2YK\n'

# %%
encrypted = [] 

for i in path_list: 
    url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/' + i
    request = requests.get(url,auth=gh_session.auth)
    text = request.json()
    message = text['content'][:-1]
    encrypted.append(message)
    
encrypted
# Out:
# ['b2YK',
#  'c3BlbnQK',
#  'MjAK',
#  'dGltZQo=',
#  'bmVlZAo=',
#  'dG8K',
#  'cGVyY2VudAo=',
#  'Y29tcGxhaW5pbmcK',
#  'aXMK',
#  'ZGF0YS4K',
#  'cHJlcGFyaW5nCg==',
#  'b2YK',
#  'ZGF0YSwK',
#  'cHJlcGFyZQo=',
#  'dGhlCg==',
#  'c2NpZW5jZSwK',
#  'ODAK',
#  'YWJvdXQK',
#  'c3BlbnQK',
#  'ZGF0YQo=',
#  'cGVyY2VudAo=',
#  'dGltZQo=',
#  'aXMK',
#  'SW4K']

# %%
import base64

# %%
message = []
for i in encrypted: 
    decr = base64.b64decode(i).decode('utf-8')
    message.append(decr[:-1])
    
message
# Out:
# ['of',
#  'spent',
#  '20',
#  'time',
#  'need',
#  'to',
#  'percent',
#  'complaining',
#  'is',
#  'data.',
#  'preparing',
#  'of',
#  'data,',
#  'prepare',
#  'the',
#  'science,',
#  '80',
#  'about',
#  'spent',
#  'data',
#  'percent',
#  'time',
#  'is',
#  'In']

# %%
#Jesus christ
