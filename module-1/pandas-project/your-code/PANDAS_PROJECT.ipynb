# %%
import os 
import pandas as pd 
import numpy as np 
import seaborn as sb

# %%
df = pd.read_csv('GSAF5.csv', delimiter=',', encoding="ISO-8859-1")

# %%
df.shape
# Out:
# (5992, 24)

# %%
df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M
# 2  New Smyrna Beach, Volusia County  Surfing             male    M
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M
# 4                       Bells Beach  Surfing             male    M
#
#       ...       Species        Investigator or Source  \
# 0     ...            NaN  Orlando Sentinel, 9/19/2016
# ...

# %%
df.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
df = df.drop(columns=['Unnamed: 22', 'Unnamed: 23','href', 'href formula', 'pdf',
                 'Case Number.1','Case Number.2','Investigator or Source', 'original order','Name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-d3f1dec50aa5> in <module>
#       1 df = df.drop(columns=['Unnamed: 22', 'Unnamed: 23','href', 'href formula', 'pdf',
# ----> 2                  'Case Number.1','Case Number.2','Investigator or Source', 'original order','Name'])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   Age  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M   16
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M   36
# 2  New Smyrna Beach, Volusia County  Surfing             male    M   43
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  NaN
# 4                       Bells Beach  Surfing             male    M  NaN
#
#                                   Injury Fatal (Y/N)   Time   Species
# ...

# %%
a = df['Time']

# %%
count = 0 


for i in a: 
    try:
        if 3< len(i) <=5: 
            b= i.split('h') 
            c= int(b[0]) + int(b[1])/60
            df['Time'][count] = c
    except: 
        pass 
    count+=1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.head(100)
# Out:
#      Case Number                  Date  Year        Type  \
# 0   2016.09.18.c             18-Sep-16  2016  Unprovoked
# 1   2016.09.18.b             18-Sep-16  2016  Unprovoked
# 2   2016.09.18.a             18-Sep-16  2016  Unprovoked
# 3     2016.09.17             17-Sep-16  2016  Unprovoked
# 4     2016.09.15             16-Sep-16  2016  Unprovoked
# 5   2016.09.15.R             15-Sep-16  2016        Boat
# 6     2016.09.11             11-Sep-16  2016  Unprovoked
# 7     2016.09.07             07-Sep-16  2016  Unprovoked
# 8     2016.09.06             06-Sep-16  2016  Unprovoked
# 9   2016.09.05.b             05-Sep-16  2016  Unprovoked
# 10  2016.09.05.a             05-Sep-16  2016  Unprovoked
# 11    2016.09.04             04-Sep-16  2016  Unprovoked
# 12    2016.09.01             01-Sep-16  2016  Unprovoked
# 13  2016.08.29.b             29-Aug-16  2016  Unprovoked
# 14  2016.08.29.a             29-Aug-16  2016  Unprovoked
# ...

# %%
count1 = 0 


for i in a: 
    try:
        if 'night' in i.lower(): 
            df['Time'][count1] = 22
        if 'morning' in i.lower(): 
            df['Time'][count1] = 9
        if 'after' in i.lower(): 
            df['Time'][count1] = 16
        if 'evening' in i.lower(): 
            df['Time'][count1] = 19
        if isinstance(i, str):
            df['Time'][count1] = float('nan')
            
        
    except: 
        
        pass
    count1+=1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ...

# %%
count1=0
for i in a: 
    try: 
        if isinstance(i, str): 
            count1+=1 
    except: 
        pass 
print(count1)
# Out:
# 0

# %%
len(df['Time'].unique())
# Out:
# 235

# %%
df.dtypes
# Out:
# Case Number    object
# Date           object
# Year            int64
# Type           object
# Country        object
# Area           object
# Location       object
# Activity       object
# Name           object
# Sex            object
# Age            object
# Injury         object
# Fatal (Y/N)    object
# Time           object
# Species        object
# dtype: object

# %%
df.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# ...

# %%
df['Time'].mean()
# Out:
# 13.405846342209971

# %%
if 'Sep' in df['Date']: 
    print(0)

# %%
count1 = 0 

series = df['Date']

for i in series: 
    try:
        if 'jan' in i.lower(): 
            df['Date'][count1] = 1
        if 'feb' in i.lower(): 
            df['Date'][count1] = 2
        if 'mar' in i.lower(): 
            df['Date'][count1] = 3
        if 'apr' in i.lower(): 
            df['Date'][count1] = 4
        if 'may' in i.lower(): 
            df['Date'][count1] = 5
        if 'jun' in i.lower(): 
            df['Date'][count1] = 6
        if 'jul' in i.lower(): 
            df['Date'][count1] = 7
        if 'aug' in i.lower(): 
            df['Date'][count1] = 8
        if 'sep' in i.lower(): 
            df['Date'][count1] = 9
        if 'oct' in i.lower(): 
            df['Date'][count1] = 10
        if 'nov' in i.lower(): 
            df['Date'][count1] = 11
        if 'dec' in i.lower(): 
            df['Date'][count1] = 12
        else: 
            df['Date'][count1] = float('nan')
            
        
    except: 
        pass
    count1+=1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(series)
# Out:
# 5992

# %%
len(series.unique())
# Out:
# 13

# %%
df
# Out:
#        Case Number Date  Year          Type             Country  \
# 0     2016.09.18.c    9  2016    Unprovoked                 USA
# 1     2016.09.18.b    9  2016    Unprovoked                 USA
# 2     2016.09.18.a    9  2016    Unprovoked                 USA
# 3       2016.09.17    9  2016    Unprovoked           AUSTRALIA
# 4       2016.09.15    9  2016    Unprovoked           AUSTRALIA
# 5     2016.09.15.R    9  2016          Boat           AUSTRALIA
# 6       2016.09.11    9  2016    Unprovoked                 USA
# 7       2016.09.07    9  2016    Unprovoked                 USA
# 8       2016.09.06    9  2016    Unprovoked       NEW CALEDONIA
# 9     2016.09.05.b    9  2016    Unprovoked                 USA
# 10    2016.09.05.a    9  2016    Unprovoked           AUSTRALIA
# 11      2016.09.04    9  2016    Unprovoked                 USA
# 12      2016.09.01    9  2016    Unprovoked                 USA
# 13    2016.08.29.b    8  2016    Unprovoked                 USA
# ...

# %%
df.head()
# Out:
#     Case Number Date  Year        Type    Country      Area  \
# 0  2016.09.18.c    9  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b    9  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a    9  2016  Unprovoked        USA   Florida
# 3    2016.09.17    9  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15    9  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity Sex   Age  \
# 0  New Smyrna Beach, Volusia County  Surfing    M   16
# 1  New Smyrna Beach, Volusia County  Surfing    M   36
# 2  New Smyrna Beach, Volusia County  Surfing    M   43
# 3                  Thirteenth Beach  Surfing    M  NaN
# 4                       Bells Beach  Surfing    M  NaN
#
#                                   Injury Fatal (Y/N)     Time   Species
# 0                  Minor injury to thigh           N       13        NaN
# 1                   Lacerations to hands           N       11        NaN
# ...

# %%
age = df['Age']
count2 = 0

for i in age: 
    try: 
        if len(i) > 2: 
            age[count2] = float('nan')
        elif isinstance(i, str): 
            age[count2] = float('nan')
        else: 
            age[count2] = int(i)
        
    except: 
        pass 
    count2 += 1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.head()
# Out:
#     Case Number Date  Year        Type    Country      Area  \
# 0  2016.09.18.c    9  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b    9  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a    9  2016  Unprovoked        USA   Florida
# 3    2016.09.17    9  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15    9  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity Sex   Age  \
# 0  New Smyrna Beach, Volusia County  Surfing    M   16
# 1  New Smyrna Beach, Volusia County  Surfing    M   36
# 2  New Smyrna Beach, Volusia County  Surfing    M   43
# 3                  Thirteenth Beach  Surfing    M  NaN
# 4                       Bells Beach  Surfing    M  NaN
#
#                                   Injury Fatal (Y/N)     Time   Species
# 0                  Minor injury to thigh           N       13        NaN
# 1                   Lacerations to hands           N       11        NaN
# ...

# %%
df['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', nan, 'UNKNOWN', ' N', 'F', 'N ', '#VALUE!', 'n'],
#       dtype=object)

# %%
#Converting Fatal Column to 0 and 1


f = df['Fatal (Y/N)']
count3 = 0

for i in f: 
    try:
        if i == 'UNKNOWN': 
            f[count3] = float('nan')
        elif 'n' in i.lower() or i == 'F':
            f[count3] = 0 
        elif i == 'Y':
            f[count3] = 1 
        else: 
            f[count3] = float('nan')
    except: 
        pass 
    count3 += 1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ...

# %%
f.unique()
# Out:
# array([0, 1, nan], dtype=object)

# %%
f.mean()
# Out:
# 0.2640353861857775

# %%
df['Date'].mean()
# Out:
# 6.582345431333212

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species '],
#       dtype='object')

# %%
#renaming columns
df = df.rename(columns={'Sex ':'Sex', 'Species ':'Species'})

# %%
df['Sex'].unique()
# Out:
# array(['M', nan, 'F', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
#Converting female 0 and male 1
s = df['Sex']
count4 = 0

for i in s: 
    try: 
        if 'm' in i.lower(): 
            s[count4] = 1
        elif 'f' in i.lower(): 
            s[count4] = 0  
        else: 
            s[count4] = float('nan')
    except: 
        pass 
    count4 += 1

# %%
print(s.mean(), s.std(), s.var(), s.unique())
# Out:
# 0.8921062338620436 0.3102748086641702 0.09627045689158742 [1 nan 0]
