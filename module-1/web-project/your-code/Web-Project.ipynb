# %% [markdown]
# # Project: API and Web Data Scraping

# %%
import quandl # package used to communicate with Quandl API
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# initial url used to obtain zip codes, can be replaced by changing the 'st' and 'county' query parameters below
url = 'https://www.bestplaces.net/find/zip.aspx?st=fl&county=12086'

# %%
html = requests.get(url).content

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
# extracts and stores zip code and neighborhood name
chowder = [element.text for element in list(soup.find_all('u')) if element.text.startswith('3')]

# %%
# split zips from neighborhoods and store into separate lists
zip_pattern = '(\d*) '
neighborhood_pattern = '\\((.+?)\\)'
zipCodes = list(map(lambda x: re.findall(zip_pattern, x), chowder))
neighborhoods = list(map(lambda x: re.findall(neighborhood_pattern, x), chowder))

# %%
# flatten lists
flatten = lambda l: [item for sublist in l for item in sublist if len(item) > 1]
zipCodes = flatten(zipCodes)
neighborhoods = flatten(neighborhoods)

# %%
# dictionary to reference later if necessary containing zip and corresponding neighborhood
ZIP_HOOD = dict(zip(zipCodes, neighborhoods))

# %%
# base url for population data
base_url = 'https://www.bestplaces.net/people/zip-code/florida/'
url_list = [base_url + neighborhood + '/' + zipCode for neighborhood, zipCode in zip(neighborhoods, zipCodes)]

# %%
# function scrapes a link and outputs any tables from html
def tableScrapeAndShape(link):
    '''takes a url and scrapes html tables into dataframes'''
    dataSoup = BeautifulSoup(requests.get(link).content, 'lxml').find_all('table')
    table = pd.read_html(str(dataSoup))[0]
    table.columns = table.iloc[0]
    table.set_index('PEOPLE', inplace=True)
    table = table.reindex(table.index.drop('PEOPLE'))
    table.index.name = None
    table = table.transpose()
    table.index.name = None
    return table

# %%
# generates table containing general information on miami-dade county neighborhoods
import multiprocessing
pool = multiprocessing.Pool()
bigTable = pd.concat(list(pool.map(tableScrapeAndShape, url_list)))
pool.terminate()
pool.join()
# Out:
# /home/fred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# united states population data is included as a reference, and concatenated each time. drop duplicates eliminates
# multiples of this same entry
bigTable = bigTable.drop_duplicates()

# %%
# examine table

bigTable.head()
# Out:
#                         Asian   Black Divorced FAMILY Family Households  \
# Aventura, Florida       0.81%   3.56%   15.38%    NaN              7684
# United States           5.29%  12.29%   10.85%    NaN          78298703
# Coral Gables, Florida   4.23%   4.65%    3.93%    NaN              2800
# Coral Gables, Florida   1.17%   0.30%   12.97%    NaN              9930
# Coral Terrace, Florida  1.16%   0.99%   14.57%    NaN             10646
#
#                        Female Population Hawaiian, Pacific Islander Hispanic  \
# Aventura, Florida                 51.88%                      0.00%   36.36%
# United States                     50.77%                      0.16%   17.60%
# Coral Gables, Florida             50.47%                      0.05%   46.78%
# Coral Gables, Florida             52.95%                      0.04%   79.23%
# Coral Terrace, Florida            53.06%                      0.00%   83.84%
#
#                        Household Size Households   ...   Population - 2000  \
# Aventura, Florida                2.13      14872   ...               20799
# United States                    2.63  118825921   ...           285036114
# Coral Gables, Florida            2.78       4018   ...               13210
# Coral Gables, Florida            2.61      16251   ...               34045
# Coral Terrace, Florida           3.22      14260   ...               44142
#
#                        Population - 2010 RACE Single Population  \
# Aventura, Florida                  30840  NaN            49.50%
# United States                  308745538  NaN            49.80%
# Coral Gables, Florida              14995  NaN            60.44%
# Coral Gables, Florida              37456  NaN            49.84%
# Coral Terrace, Florida             43788  NaN            51.61%
#
#                        Single, no children Single, w/children  \
# Aventura, Florida                   10.27%              8.04%
# United States                       10.27%             16.35%
# Coral Gables, Florida                6.29%              6.64%
# Coral Gables, Florida               14.86%             11.82%
# Coral Terrace, Florida              17.46%             13.48%
#
#                        Two or More Races Water Area   White Widowed
# Aventura, Florida                  1.10%          1  57.95%   8.66%
# United States                      2.32%     264837  61.46%   5.83%
# Coral Gables, Florida              1.71%          0  42.29%   3.69%
# Coral Gables, Florida              0.75%          0  18.40%   6.96%
# Coral Terrace, Florida             0.84%          1  13.08%   7.25%
#
# [5 rows x 37 columns]

# %%
# remove columns containing null entries
null_cols = bigTable.isnull().sum()

# set a threshold to remove columns with more than a quarter null  entries
threshold  = (0.25) * len(bigTable.index)
drop_cols = list(null_cols[null_cols > threshold].index)

# %%
# drop columns
bigTable = bigTable.drop(drop_cols, axis = 1)
bigTable.head(10)
# Out:
#                         Asian   Black Divorced Family Households  \
# Aventura, Florida       0.81%   3.56%   15.38%              7684
# United States           5.29%  12.29%   10.85%          78298703
# Coral Gables, Florida   4.23%   4.65%    3.93%              2800
# Coral Gables, Florida   1.17%   0.30%   12.97%              9930
# Coral Terrace, Florida  1.16%   0.99%   14.57%             10646
# Country Club, Florida   1.00%   6.42%   12.36%             15547
# Cutler Bay, Florida     1.37%  18.66%   15.97%              5732
# Cutler Bay, Florida     2.83%  19.23%   14.41%              3817
# Doral, Florida          2.80%   1.83%   11.47%             12197
# Florida City, Florida   0.00%  31.80%   13.61%              3905
#
#                        Female Population Hawaiian, Pacific Islander Hispanic  \
# Aventura, Florida                 51.88%                      0.00%   36.36%
# United States                     50.77%                      0.16%   17.60%
# Coral Gables, Florida             50.47%                      0.05%   46.78%
# Coral Gables, Florida             52.95%                      0.04%   79.23%
# Coral Terrace, Florida            53.06%                      0.00%   83.84%
# Country Club, Florida             51.33%                      0.00%   84.45%
# Cutler Bay, Florida               48.35%                      0.00%   60.55%
# Cutler Bay, Florida               51.34%                      0.12%   58.65%
# Doral, Florida                    52.88%                      0.00%   83.30%
# Florida City, Florida             46.29%                      0.00%   54.35%
#
#                        Household Size Households Land Area   ...    \
# Aventura, Florida                2.13      14872         3   ...
# United States                    2.63  118825921   3531905   ...
# Coral Gables, Florida            2.78       4018         3   ...
# Coral Gables, Florida            2.61      16251         5   ...
# Coral Terrace, Florida           3.22      14260         7   ...
# Country Club, Florida            3.14      21053         6   ...
# Cutler Bay, Florida               3.5       7763         6   ...
# Cutler Bay, Florida               3.5       4478         2   ...
# Doral, Florida                   3.46      14287        56   ...
# Florida City, Florida               4       4812       280   ...
#
#                        Population - 1990 Population - 2000 Population - 2010  \
# Aventura, Florida                  15498             20799             30840
# United States                  251960433         285036114         308745538
# Coral Gables, Florida              14704             13210             14995
# Coral Gables, Florida              33349             34045             37456
# Coral Terrace, Florida             43251             44142             43788
# Country Club, Florida              30229             49279             63544
# Cutler Bay, Florida                16777             20280             23828
# Cutler Bay, Florida                 1919              4820             11593
# Doral, Florida                      5013             15272             39489
# Florida City, Florida              12141             15402             18613
#
#                        Single Population Single, no children  \
# Aventura, Florida                 49.50%              10.27%
# United States                     49.80%              10.27%
# Coral Gables, Florida             60.44%               6.29%
# Coral Gables, Florida             49.84%              14.86%
# Coral Terrace, Florida            51.61%              17.46%
# Country Club, Florida             50.34%              14.26%
# Cutler Bay, Florida               55.14%              13.42%
# Cutler Bay, Florida               52.07%              14.57%
# Doral, Florida                    43.74%               9.52%
# Florida City, Florida             64.79%              13.39%
#
#                        Single, w/children Two or More Races Water Area  \
# Aventura, Florida                   8.04%             1.10%          1
# United States                      16.35%             2.32%     264837
# Coral Gables, Florida               6.64%             1.71%          0
# Coral Gables, Florida              11.82%             0.75%          0
# Coral Terrace, Florida             13.48%             0.84%          1
# Country Club, Florida              21.29%             0.13%          1
# Cutler Bay, Florida                20.45%             0.56%          0
# Cutler Bay, Florida                28.24%             1.91%          0
# Doral, Florida                     16.98%             0.10%          8
# Florida City, Florida              35.42%             0.56%         24
#
#                          White Widowed
# Aventura, Florida       57.95%   8.66%
# United States           61.46%   5.83%
# Coral Gables, Florida   42.29%   3.69%
# Coral Gables, Florida   18.40%   6.96%
# Coral Terrace, Florida  13.08%   7.25%
# Country Club, Florida    7.72%   3.95%
# Cutler Bay, Florida     18.57%   3.37%
# Cutler Bay, Florida     14.82%   2.75%
# Doral, Florida          11.96%   3.04%
# Florida City, Florida   13.05%   3.87%
#
# [10 rows x 35 columns]

# %%
# clean state name from index for easier matching later
bigTable = bigTable.rename(index=lambda x: x.replace(', Florida', ''))
bigTable.head(5)
# Out:
#                Asian   Black Divorced Family Households Female Population  \
# Aventura       0.81%   3.56%   15.38%              7684            51.88%
# United States  5.29%  12.29%   10.85%          78298703            50.77%
# Coral Gables   4.23%   4.65%    3.93%              2800            50.47%
# Coral Gables   1.17%   0.30%   12.97%              9930            52.95%
# Coral Terrace  1.16%   0.99%   14.57%             10646            53.06%
#
#               Hawaiian, Pacific Islander Hispanic Household Size Households  \
# Aventura                           0.00%   36.36%           2.13      14872
# United States                      0.16%   17.60%           2.63  118825921
# Coral Gables                       0.05%   46.78%           2.78       4018
# Coral Gables                       0.04%   79.23%           2.61      16251
# Coral Terrace                      0.00%   83.84%           3.22      14260
#
#               Land Area   ...   Population - 1990 Population - 2000  \
# Aventura              3   ...               15498             20799
# United States   3531905   ...           251960433         285036114
# Coral Gables          3   ...               14704             13210
# Coral Gables          5   ...               33349             34045
# Coral Terrace         7   ...               43251             44142
#
#               Population - 2010 Single Population Single, no children  \
# Aventura                  30840            49.50%              10.27%
# United States         308745538            49.80%              10.27%
# Coral Gables              14995            60.44%               6.29%
# Coral Gables              37456            49.84%              14.86%
# Coral Terrace             43788            51.61%              17.46%
#
#               Single, w/children Two or More Races Water Area   White Widowed
# Aventura                   8.04%             1.10%          1  57.95%   8.66%
# United States             16.35%             2.32%     264837  61.46%   5.83%
# Coral Gables               6.64%             1.71%          0  42.29%   3.69%
# Coral Gables              11.82%             0.75%          0  18.40%   6.96%
# Coral Terrace             13.48%             0.84%          1  13.08%   7.25%
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Zillow Home Value Index for Miami-Dade County
# ### Price of home to rent ratio

# %%
# dictionary of Zip codes and dataset summary codes

def pprZipCode(zipCode):
    '''uses zip code to obtain price to rent ratio using quandl and zillow API'''
    try:
        temp = (quandl.get('ZILLOW/Z' + zipCode + '_PRRAH', collapse='annual', order = 'desc')).rename(columns = {'Value' : ZIP_HOOD.get(zipCode)})
        temp.index.name = None
        temp = temp.transpose()
        temp.index.name = None
        return temp
    except:
        pass

# %%
# access Quandl api for price of home to rent ratios for each zip code
pool = multiprocessing.Pool()
pprTable = pd.concat(list(pool.map(pprZipCode, zipCodes)))
pool.terminate()
pool.join()

# %%
pprTable.head()
# Out:
#                2010-12-31  2011-12-31  2012-12-31  2013-12-31  2014-12-31  \
# Aventura            11.47       11.87       12.55       13.24       13.23
# Coral Gables        12.86       13.50       14.02       15.03       15.29
# Coral Gables        12.34       12.16       12.93       14.21       14.23
# Coral Terrace        9.78        8.99        9.79       10.56       11.05
# Country Club         6.93        6.82        7.33        7.87        9.08
#
#                2015-12-31  2016-12-31  2017-12-31  2018-12-31  2019-12-31
# Aventura            12.62       12.87       12.67       12.27        7.36
# Coral Gables        14.69       15.12       15.18       15.52        2.82
# Coral Gables        13.62       14.19       14.64       14.92        4.88
# Coral Terrace       11.93       12.83       13.46       13.92        7.35
# Country Club         9.44       10.08       11.21       11.46       10.41

# %%
colnames = [year for year in pprTable.columns.year]

# %%
pprTable.columns = colnames
#pprTable.columns = pd.MultiIndex.from_product([['Year'], colnames])

# %%
pprTable.head()
# Out:
#                 2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# Aventura       11.47  11.87  12.55  13.24  13.23  12.62  12.87  12.67  12.27
# Coral Gables   12.86  13.50  14.02  15.03  15.29  14.69  15.12  15.18  15.52
# Coral Gables   12.34  12.16  12.93  14.21  14.23  13.62  14.19  14.64  14.92
# Coral Terrace   9.78   8.99   9.79  10.56  11.05  11.93  12.83  13.46  13.92
# Country Club    6.93   6.82   7.33   7.87   9.08   9.44  10.08  11.21  11.46
#
#                 2019
# Aventura        7.36
# Coral Gables    2.82
# Coral Gables    4.88
# Coral Terrace   7.35
# Country Club   10.41

# %%
# merge both tables on index

results = bigTable.join(pprTable)

# %%
results.head()
# Out:
#               Asian  Black Divorced Family Households Female Population  \
# Aventura      0.81%  3.56%   15.38%              7684            51.88%
# Coral Gables  4.23%  4.65%    3.93%              2800            50.47%
# Coral Gables  4.23%  4.65%    3.93%              2800            50.47%
# Coral Gables  1.17%  0.30%   12.97%              9930            52.95%
# Coral Gables  1.17%  0.30%   12.97%              9930            52.95%
#
#              Hawaiian, Pacific Islander Hispanic Household Size Households  \
# Aventura                          0.00%   36.36%           2.13      14872
# Coral Gables                      0.05%   46.78%           2.78       4018
# Coral Gables                      0.05%   46.78%           2.78       4018
# Coral Gables                      0.04%   79.23%           2.61      16251
# Coral Gables                      0.04%   79.23%           2.61      16251
#
#              Land Area  ...    2010   2011   2012   2013   2014   2015   2016  \
# Aventura             3  ...   11.47  11.87  12.55  13.24  13.23  12.62  12.87
# Coral Gables         3  ...   12.86  13.50  14.02  15.03  15.29  14.69  15.12
# Coral Gables         3  ...   12.34  12.16  12.93  14.21  14.23  13.62  14.19
# Coral Gables         5  ...   12.86  13.50  14.02  15.03  15.29  14.69  15.12
# Coral Gables         5  ...   12.34  12.16  12.93  14.21  14.23  13.62  14.19
#
#                2017   2018  2019
# Aventura      12.67  12.27  7.36
# Coral Gables  15.18  15.52  2.82
# Coral Gables  14.64  14.92  4.88
# Coral Gables  15.18  15.52  2.82
# Coral Gables  14.64  14.92  4.88
#
# [5 rows x 45 columns]

# %%
# remove columns containing null entries
null_cols = results.isnull().sum()

# %%
results.dropna(thresh=10, inplace=True)
results = results.fillna(0)

# %%
for column in results.columns:
    results[column] = results[column].astype('str')
    try:
        results[column] = results[column].str.rstrip('%').astype('float')
    except:
        pass

# %%
#results.dtypes

# %%
resultsFloat = results.groupby(results.index).mean()

# %%
resultsFloat.head()
# Out:
#                Asian   Black  Divorced  Family Households  Female Population  \
# Aventura        0.81   3.560     15.38             7684.0             51.880
# Coral Gables    2.70   2.475      8.45             6365.0             51.710
# Coral Terrace   1.16   0.990     14.57            10646.0             53.060
# Country Club    1.00   6.420     12.36            15547.0             51.330
# Cutler Bay      2.10  18.945     15.19             4774.5             49.845
#
#                Hawaiian, Pacific Islander  Hispanic  Household Size  \
# Aventura                            0.000    36.360           2.130
# Coral Gables                        0.045    63.005           2.695
# Coral Terrace                       0.000    83.840           3.220
# Country Club                        0.000    84.450           3.140
# Cutler Bay                          0.060    59.600           3.500
#
#                Households  Land Area   ...     2010   2011    2012   2013  \
# Aventura          14872.0        3.0   ...    11.47  11.87  12.550  13.24
# Coral Gables      10134.5        4.0   ...    12.60  12.83  13.475  14.62
# Coral Terrace     14260.0        7.0   ...     9.78   8.99   9.790  10.56
# Country Club      21053.0        6.0   ...     6.93   6.82   7.330   7.87
# Cutler Bay         6120.5        4.0   ...     6.92   6.76   7.035   8.47
#
#                  2014    2015    2016    2017    2018    2019
# Aventura       13.230  12.620  12.870  12.670  12.270   7.360
# Coral Gables   14.760  14.155  14.655  14.910  15.220   3.850
# Coral Terrace  11.050  11.930  12.830  13.460  13.920   7.350
# Country Club    9.080   9.440  10.080  11.210  11.460  10.410
# Cutler Bay      9.355  10.015  10.875  11.505  12.375   7.125
#
# [5 rows x 44 columns]

# %%
resultsFloat.to_csv('output/results.csv', encoding='utf-8')
