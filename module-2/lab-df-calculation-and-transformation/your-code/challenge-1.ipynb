# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **pokemons**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# ### Import all required libraries

# %%
# import libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set
pokemon = pd.read_csv('/Users/gissellec/Desktop/IronHack/datamia0619/module-2/lab-df-calculation-and-transformation/your-code/pokemon.csv')

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
# enter your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# ### Obtain the distinct values across `Type 1` and `Type 2`
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# enter your code here
typearray=pd.unique(pokemon[['Type 1', 'Type 2']].values.ravel('K'))
typearray
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %% [markdown]
# ### Cleanup `Name` that contain "Mega"
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# enter your code here

import re
pokemon['Name'].replace({'(.*Mega\s)':''}, regex=True,inplace=True)
# test transformed data

pokemon.head(10)
# Out:
#    #         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1    Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2      Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3     Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Venusaur  Grass  Poison    625  80     100      123      122
# 4  4   Charmander   Fire     NaN    309  39      52       43       60
# 5  5   Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6    Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7     Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# enter your code here
pokemon['A/D Ratio'] = pokemon['Attack'] / pokemon['Defense']

# %% [markdown]
# ### Identify the pokemon with the highest `A/D Ratio`

# %%
# enter your code here
pokemon.loc[pokemon['A/D Ratio'].idxmax()]
# Out:
# #                            386
# Name          DeoxysAttack Forme
# Type 1                   Psychic
# Type 2                       NaN
# Total                        600
# HP                            50
# Attack                       180
# Defense                       20
# Sp. Atk                      180
# Sp. Def                       20
# Speed                        150
# Generation                     3
# Legendary                   True
# A/D Ratio                      9
# Name: 429, dtype: object

# %% [markdown]
# ### Identify the pokemon with the lowest A/D Ratio

# %%
# enter your code here
pokemon.loc[pokemon['A/D Ratio'].idxmin()]
# Out:
# #                   213
# Name            Shuckle
# Type 1              Bug
# Type 2             Rock
# Total               505
# HP                   20
# Attack               10
# Defense             230
# Sp. Atk              10
# Sp. Def             230
# Speed                 5
# Generation            2
# Legendary         False
# A/D Ratio     0.0434783
# Name: 230, dtype: object

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# enter your code here
pokemon['Combo Type'] = np.where(pokemon['Type 2'] != 'NaN', pokemon['Type 1']+"-"+pokemon['Type 2'].map(str), pokemon['Type 1'])
pokemon.head(10)
# Out:
#    #         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1    Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2      Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3     Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Venusaur  Grass  Poison    625  80     100      123      122
# 4  4   Charmander   Fire     NaN    309  39      52       43       60
# 5  5   Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6    Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7     Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0       65     45           1      False   1.000000  Grass-Poison
# 1       80     60           1      False   0.984127  Grass-Poison
# 2      100     80           1      False   0.987952  Grass-Poison
# 3      120     80           1      False   0.813008  Grass-Poison
# 4       50     65           1      False   1.209302      Fire-nan
# 5       65     80           1      False   1.103448      Fire-nan
# 6       85    100           1      False   1.076923   Fire-Flying
# 7       85    100           1      False   1.171171   Fire-Dragon
# 8      115    100           1      False   1.333333   Fire-Flying
# 9       64     43           1      False   0.738462     Water-nan

# %%
pokemon['Combo Type'].replace({'-nan':''}, regex=True,inplace=True)

# %%
pokemon.head(10)
# Out:
#    #         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1    Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2      Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3     Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Venusaur  Grass  Poison    625  80     100      123      122
# 4  4   Charmander   Fire     NaN    309  39      52       43       60
# 5  5   Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6    Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7     Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0       65     45           1      False   1.000000  Grass-Poison
# 1       80     60           1      False   0.984127  Grass-Poison
# 2      100     80           1      False   0.987952  Grass-Poison
# 3      120     80           1      False   0.813008  Grass-Poison
# 4       50     65           1      False   1.209302          Fire
# 5       65     80           1      False   1.103448          Fire
# 6       85    100           1      False   1.076923   Fire-Flying
# 7       85    100           1      False   1.171171   Fire-Dragon
# 8      115    100           1      False   1.333333   Fire-Flying
# 9       64     43           1      False   0.738462         Water

# %% [markdown]
# ### Identify the pokemons whose `A/D Ratio` are among the top 5

# %%
# enter your code here
top5 = pokemon.sort_values(['A/D Ratio'], ascending=[False])
top55=top5.head(5)

# %%
top55
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15            Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000     Psychic
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125        Rock
# 348       95       40     95           3      False      3.000  Water-Dark

# %% [markdown]
# ### For the 5 pokemons printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemons with the highest `A/D Ratio`.

# %%
# enter your code here
top55
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15            Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000     Psychic
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125        Rock
# 348       95       40     95           3      False      3.000  Water-Dark

# %%
top55
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15            Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000     Psychic
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125        Rock
# 348       95       40     95           3      False      3.000  Water-Dark

# %% [markdown]
# ### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemons.
#
# Your output should look like below:
#
# ![Aggregate](aggregated-mean.png)

# %%
# enter your code here
#newtab=pd.merge(pokemon, top55, on='Combo Type', how='inner')
newtab
##newtab.drop(newtab.columns[[25, 28]], axis=1, inplace=True)

# %%
newtab.drop('#_y', axis=1)
newtab
# Out:
#     #_x              Name_x Type 1_x Type 2_x  Total_x  HP_x  Attack_x  \
# 0    13              Weedle      Bug   Poison      195    40        35
# 1    14              Kakuna      Bug   Poison      205    45        25
# 2    15            Beedrill      Bug   Poison      395    65        90
# 3    15            Beedrill      Bug   Poison      495    65       150
# 4    48             Venonat      Bug   Poison      305    60        55
# 5    49            Venomoth      Bug   Poison      450    70        65
# 6   167            Spinarak      Bug   Poison      250    40        60
# 7   168             Ariados      Bug   Poison      390    70        90
# 8   269              Dustox      Bug   Poison      385    60        50
# 9   543            Venipede      Bug   Poison      260    30        45
# 10  544          Whirlipede      Bug   Poison      360    40        55
# 11  545           Scolipede      Bug   Poison      485    60       100
# 12   63                Abra  Psychic      NaN      310    25        20
# 13   64             Kadabra  Psychic      NaN      400    40        35
# 14   65            Alakazam  Psychic      NaN      500    55        50
# 15   65            Alakazam  Psychic      NaN      590    55        50
# 16   96             Drowzee  Psychic      NaN      328    60        48
# 17   97               Hypno  Psychic      NaN      483    85        73
# 18  150              Mewtwo  Psychic      NaN      680   106       110
# 19  150            Mewtwo Y  Psychic      NaN      780   106       150
# 20  151                 Mew  Psychic      NaN      600   100       100
# 21  196              Espeon  Psychic      NaN      525    65        65
# 22  201               Unown  Psychic      NaN      336    48        72
# 23  202           Wobbuffet  Psychic      NaN      405   190        33
# 24  325              Spoink  Psychic      NaN      330    60        25
# 25  326             Grumpig  Psychic      NaN      470    80        45
# 26  358            Chimecho  Psychic      NaN      425    65        50
# 27  360              Wynaut  Psychic      NaN      260    95        23
# 28  386  DeoxysNormal Forme  Psychic      NaN      600    50       150
# 29  386  DeoxysAttack Forme  Psychic      NaN      600    50       180
# ..  ...                 ...      ...      ...      ...   ...       ...
# 41  576          Gothitelle  Psychic      NaN      490    70        55
# 42  577             Solosis  Psychic      NaN      290    45        30
# 43  578             Duosion  Psychic      NaN      370    65        40
# 44  579           Reuniclus  Psychic      NaN      490   110        65
# 45  605              Elgyem  Psychic      NaN      335    55        55
# 46  606            Beheeyem  Psychic      NaN      485    75        75
# 47  677              Espurr  Psychic      NaN      355    62        48
# 48  678        MeowsticMale  Psychic      NaN      466    74        48
# 49  678      MeowsticFemale  Psychic      NaN      466    74        48
# 50  130            Gyarados    Water     Dark      640    95       155
# 51  130            Gyarados    Water     Dark      640    95       155
# 52  318            Carvanha    Water     Dark      305    45        90
# 53  318            Carvanha    Water     Dark      305    45        90
# 54  319            Sharpedo    Water     Dark      460    70       120
# 55  319            Sharpedo    Water     Dark      460    70       120
# 56  319            Sharpedo    Water     Dark      560    70       140
# 57  319            Sharpedo    Water     Dark      560    70       140
# 58  342           Crawdaunt    Water     Dark      468    63       120
# 59  342           Crawdaunt    Water     Dark      468    63       120
# 60  658            Greninja    Water     Dark      530    72        95
# 61  658            Greninja    Water     Dark      530    72        95
# 62  185           Sudowoodo     Rock      NaN      410    70       100
# 63  299            Nosepass     Rock      NaN      375    30        45
# 64  377            Regirock     Rock      NaN      580    80       100
# 65  408            Cranidos     Rock      NaN      350    67       125
# 66  409           Rampardos     Rock      NaN      495    97       165
# 67  438              Bonsly     Rock      NaN      290    50        80
# 68  524          Roggenrola     Rock      NaN      280    55        75
# 69  525             Boldore     Rock      NaN      390    70       105
# 70  526            Gigalith     Rock      NaN      515    85       135
#
#     Defense_x  Sp. Atk_x  Sp. Def_x  Speed_x  Generation_x  Legendary_x  \
# 0          30         20         20       50             1        False
# 1          50         25         25       35             1        False
# 2          40         45         80       75             1        False
# 3          40         15         80      145             1        False
# 4          50         40         55       45             1        False
# 5          60         90         75       90             1        False
# 6          40         40         40       30             2        False
# 7          70         60         60       40             2        False
# 8          70         50         90       65             3        False
# 9          59         30         39       57             5        False
# 10         99         40         79       47             5        False
# 11         89         55         69      112             5        False
# 12         15        105         55       90             1        False
# 13         30        120         70      105             1        False
# 14         45        135         95      120             1        False
# 15         65        175         95      150             1        False
# 16         45         43         90       42             1        False
# 17         70         73        115       67             1        False
# 18         90        154         90      130             1         True
# 19         70        194        120      140             1         True
# 20        100        100        100      100             1        False
# 21         60        130         95      110             2        False
# 22         48         72         48       48             2        False
# 23         58         33         58       33             2        False
# 24         35         70         80       60             3        False
# 25         65         90        110       80             3        False
# 26         70         95         80       65             3        False
# 27         48         23         48       23             3        False
# 28         50        150         50      150             3         True
# 29         20        180         20      150             3         True
# ..        ...        ...        ...      ...           ...          ...
# 41         95         95        110       65             5        False
# 42         40        105         50       20             5        False
# 43         50        125         60       30             5        False
# 44         75        125         85       30             5        False
# 45         55         85         55       30             5        False
# 46         75        125         95       40             5        False
# 47         54         63         60       68             6        False
# 48         76         83         81      104             6        False
# 49         76         83         81      104             6        False
# 50        109         70        130       81             1        False
# 51        109         70        130       81             1        False
# 52         20         65         20       65             3        False
# 53         20         65         20       65             3        False
# 54         40         95         40       95             3        False
# 55         40         95         40       95             3        False
# 56         70        110         65      105             3        False
# 57         70        110         65      105             3        False
# 58         85         90         55       55             3        False
# 59         85         90         55       55             3        False
# 60         67        103         71      122             6        False
# 61         67        103         71      122             6        False
# 62        115         30         65       30             2        False
# 63        135         45         90       30             3        False
# 64        200         50        100       50             3         True
# 65         40         30         30       58             4        False
# 66         60         65         50       58             4        False
# 67         95         10         45       10             4        False
# 68         85         25         25       15             5        False
# 69        105         50         40       20             5        False
# 70        130         60         80       25             5        False
#
#     A/D Ratio_x  Combo Type  #_y              Name_y Type 1_y Type 2_y
# 0      1.166667  Bug-Poison   15            Beedrill      Bug   Poison
# 1      0.500000  Bug-Poison   15            Beedrill      Bug   Poison
# 2      2.250000  Bug-Poison   15            Beedrill      Bug   Poison
# 3      3.750000  Bug-Poison   15            Beedrill      Bug   Poison
# 4      1.100000  Bug-Poison   15            Beedrill      Bug   Poison
# 5      1.083333  Bug-Poison   15            Beedrill      Bug   Poison
# 6      1.500000  Bug-Poison   15            Beedrill      Bug   Poison
# 7      1.285714  Bug-Poison   15            Beedrill      Bug   Poison
# 8      0.714286  Bug-Poison   15            Beedrill      Bug   Poison
# 9      0.762712  Bug-Poison   15            Beedrill      Bug   Poison
# 10     0.555556  Bug-Poison   15            Beedrill      Bug   Poison
# 11     1.123596  Bug-Poison   15            Beedrill      Bug   Poison
# 12     1.333333     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 13     1.166667     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 14     1.111111     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 15     0.769231     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 16     1.066667     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 17     1.042857     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 18     1.222222     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 19     2.142857     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 20     1.000000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 21     1.083333     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 22     1.500000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 23     0.568966     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 24     0.714286     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 25     0.692308     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 26     0.714286     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 27     0.479167     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 28     3.000000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 29     9.000000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# ..          ...         ...  ...                 ...      ...      ...
# 41     0.578947     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 42     0.750000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 43     0.800000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 44     0.866667     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 45     1.000000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 46     1.000000     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 47     0.888889     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 48     0.631579     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 49     0.631579     Psychic  386  DeoxysAttack Forme  Psychic      NaN
# 50     1.422018  Water-Dark  318            Carvanha    Water     Dark
# 51     1.422018  Water-Dark  319            Sharpedo    Water     Dark
# 52     4.500000  Water-Dark  318            Carvanha    Water     Dark
# 53     4.500000  Water-Dark  319            Sharpedo    Water     Dark
# 54     3.000000  Water-Dark  318            Carvanha    Water     Dark
# 55     3.000000  Water-Dark  319            Sharpedo    Water     Dark
# 56     2.000000  Water-Dark  318            Carvanha    Water     Dark
# 57     2.000000  Water-Dark  319            Sharpedo    Water     Dark
# 58     1.411765  Water-Dark  318            Carvanha    Water     Dark
# 59     1.411765  Water-Dark  319            Sharpedo    Water     Dark
# 60     1.417910  Water-Dark  318            Carvanha    Water     Dark
# 61     1.417910  Water-Dark  319            Sharpedo    Water     Dark
# 62     0.869565        Rock  408            Cranidos     Rock      NaN
# 63     0.333333        Rock  408            Cranidos     Rock      NaN
# 64     0.500000        Rock  408            Cranidos     Rock      NaN
# 65     3.125000        Rock  408            Cranidos     Rock      NaN
# 66     2.750000        Rock  408            Cranidos     Rock      NaN
# 67     0.842105        Rock  408            Cranidos     Rock      NaN
# 68     0.882353        Rock  408            Cranidos     Rock      NaN
# 69     1.000000        Rock  408            Cranidos     Rock      NaN
# 70     1.038462        Rock  408            Cranidos     Rock      NaN
#
# [71 rows x 19 columns]

# %%
newtab.groupby('Combo Type').agg('mean')
# Out:
#                    #_x     Total_x       HP_x    Attack_x   Defense_x  \
# Combo Type
# Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic     381.973684  464.552632  72.552632   64.947368   67.236842
# Rock        410.111111  409.444444  67.111111  103.333333  107.222222
# Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
#
#             Sp. Atk_x  Sp. Def_x    Speed_x  Generation_x  Legendary_x  \
# Combo Type
# Bug-Poison  42.500000  59.333333  65.916667      2.333333     0.000000
# Psychic     98.552632  82.394737  78.868421      3.342105     0.236842
# Rock        40.555556  58.333333  32.888889      3.888889     0.111111
# Water-Dark  88.833333  63.500000  87.166667      3.166667     0.000000
#
#             A/D Ratio_x    #_y
# Combo Type
# Bug-Poison     1.315989   15.0
# Psychic        1.164196  386.0
# Rock           1.260091  408.0
# Water-Dark     2.291949  318.5
