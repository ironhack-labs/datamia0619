# %%
import pandas as pd
students = pd.read_csv('student-mat.csv')

# %%
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
students.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
students.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
students.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
students.shape
# Out:
# (395, 33)

# %%
students.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
students['age'].max()
# Out:
# 22

# %%
students['age'].min()
# Out:
# 15

# %%
students._get_numeric_data().head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %%
import numpy as np
import seaborn as sns

# %%
students.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E0494ED8D0>,
# ...
#       dtype=object)

# %%
students.groupby(students['sex']).agg({'higher':['count']})
# Out:
#     higher
#      count
# sex
# F      208
# M      187

# %%
students.pivot_table(index = 'sex'), values

# %%
student_categorical = student.select_dtypes(include = 'object')
student_categorical.head(5)
# Out:
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no  yes         no     yes    yes      yes       no
# 3        no    yes  yes        yes     yes    yes      yes      yes
# 4        no    yes  yes         no     yes    yes       no       no

# %%
students['sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
pd.crosstab(index=student.sex, columns="count")
# Out:
# col_0  count
# sex
# F        208
# M        187

# %%
student.groupby(['address', 'famsize']).agg({'famsize':'count'})
# Out:
#                  famsize
# address famsize
# R       GT3           68
#         LE3           20
# U       GT3          213
#         LE3           94

# %%
pd.crosstab(index=student.address, columns=student.famsize) #same but neater
# Out:
# famsize  GT3  LE3
# address
# R         68   20
# U        213   94
