# %%
import numpy as np
import pandas as pd
vehicles = pd.read_csv('C:/Users/regi_/OneDrive/Documents/Ironhack/datamia0619/module-1/lab-intro-pandas/your-code/vehicles.csv')

# %%
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
vehicles.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
vehicles.dtypes
# Out:
# Make                        object
# Model                       object
# Year                         int64
# Engine Displacement        float64
# Cylinders                  float64
# Transmission                object
# Drivetrain                  object
# Vehicle Class               object
# Fuel Type                   object
# Fuel Barrels/Year          float64
# City MPG                     int64
# Highway MPG                  int64
# Combined MPG                 int64
# CO2 Emission Grams/Mile    float64
# Fuel Cost/Year               int64
# dtype: object

# %%
vehicles.max()
# Out:
# Make                                            smart
# Model                                              xD
# Year                                             2017
# Engine Displacement                               8.4
# Cylinders                                          16
# Transmission                               Manual(M7)
# Drivetrain                           Rear-Wheel Drive
# Vehicle Class                    Vans, Passenger Type
# Fuel Type                  Regular Gas or Electricity
# Fuel Barrels/Year                             47.0871
# City MPG                                           58
# Highway MPG                                        61
# Combined MPG                                       56
# CO2 Emission Grams/Mile                       1269.57
# Fuel Cost/Year                                   5800
# dtype: object

# %%
import matplotlib
# %matplotlib inline

vehicles.boxplot()

# %%
vehicles.boxplot(figsize=(16,8))

# %%
vehicles.index
# Out:
# RangeIndex(start=0, stop=35952, step=1)

# %%
vehicles.index.values
# Out:
# array([    0,     1,     2, ..., 35949, 35950, 35951], dtype=int64)

# %%
vehicles[0:10]
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
# 5             Acura          2.2CL/3.0CL  1997                  2.2
# 6             Acura          2.2CL/3.0CL  1997                  2.2
# 7             Acura          2.2CL/3.0CL  1997                  3.0
# 8             Acura          2.3CL/3.0CL  1998                  2.3
# 9             Acura          2.3CL/3.0CL  1998                  2.3
#
#    Cylinders     Transmission         Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# ...

# %%
vehicles[9:10]
# Out:
#     Make        Model  Year  Engine Displacement  Cylinders  Transmission  \
# 9  Acura  2.3CL/3.0CL  1998                  2.3        4.0  Manual 5-spd
#
#           Drivetrain    Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 9  Front-Wheel Drive  Subcompact Cars   Regular           13.73375        21
#
#    Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 9           29            24               370.291667            1400

# %%
vehicles.iloc[2][3]
# Out:
# 2.5

# %%
vehicles['Engine Displacement'][2]
# Out:
# 2.5

# %%
vehicles.iloc[2][3:6]
# Out:
# Engine Displacement                2.5
# Cylinders                            4
# Transmission           Automatic 3-spd
# Name: 2, dtype: object

# %%
# in loc you need to give the name of the column. with iloc just index
vehicles.loc[2:9]['Year']
# Out:
# 2    1985
# 3    1985
# 4    1987
# 5    1997
# 6    1997
# 7    1997
# 8    1998
# 9    1998
# Name: Year, dtype: int64

# %%
newDF = vehicles[vehicles['Engine Displacement'] < 4]
newDF.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 4  ASC Incorporated                  GNX  1987                  3.8
# 5             Acura          2.2CL/3.0CL  1997                  2.2
# 6             Acura          2.2CL/3.0CL  1997                  2.2
#
#    Cylinders     Transmission         Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd   Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd   Rear-Wheel Drive                 Midsize Cars
# 5        4.0  Automatic 4-spd  Front-Wheel Drive              Subcompact Cars
# 6        4.0     Manual 5-spd  Front-Wheel Drive              Subcompact Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
newDF = vehicles[vehicles['Engine Displacement'] < 4]  & [vehicles[vehicles['Highway MPG']>30]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-81f8d6257b1c> in <module>
# ----> 1 newDF = vehicles[vehicles['Engine Displacement'] < 4]  & [vehicles[vehicles['Highway MPG']>30]]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    2016     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    2017
# -> 2018         other = _align_method_FRAME(self, other, axis)
#    2019
#    2020         if isinstance(other, ABCDataFrame):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops.py in _align_method_FRAME(left, right, axis)
#    1983           not isinstance(right, (ABCSeries, ABCDataFrame))):
#    1984         # GH17901
# -> 1985         right = to_series(right)
#    1986
#    1987     return right
#
# ...

# %%
vehicles[vehicles['Highway MPG'] > 1.5 * vehicles['City MPG']]
# Out:
#                         Make            Model  Year  Engine Displacement  \
# 10                     Acura      2.3CL/3.0CL  1998                  3.0
# 13                     Acura      2.3CL/3.0CL  1999                  3.0
# 21                     Acura            3.2CL  2001                  3.2
# 22                     Acura            3.2CL  2002                  3.2
# 23                     Acura            3.2CL  2003                  3.2
# 24                     Acura            3.2CL  2003                  3.2
# 26                     Acura            3.2TL  2000                  3.2
# 27                     Acura            3.2TL  2001                  3.2
# 28                     Acura            3.2TL  2002                  3.2
# 29                     Acura            3.2TL  2003                  3.2
# 108                    Acura           Legend  1993                  3.2
# 200                    Acura              RLX  2014                  3.5
# ...

# %%
vehicles[vehicles['Year'] == 2001].head()
# Out:
#      Make    Model  Year  Engine Displacement  Cylinders     Transmission  \
# 21  Acura    3.2CL  2001                  3.2        6.0   Automatic (S5)
# 27  Acura    3.2TL  2001                  3.2        6.0   Automatic (S5)
# 35  Acura    3.5RL  2001                  3.5        6.0  Automatic 4-spd
# 88  Acura  Integra  2001                  1.8        4.0  Automatic 4-spd
# 89  Acura  Integra  2001                  1.8        4.0     Manual 5-spd
#
#            Drivetrain    Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 21  Front-Wheel Drive     Compact Cars   Premium          16.480500        17
# 27  Front-Wheel Drive     Midsize Cars   Premium          16.480500        17
# 35  Front-Wheel Drive     Midsize Cars   Premium          18.311667        16
# 88  Front-Wheel Drive  Subcompact Cars   Regular          14.330870        21
# 89  Front-Wheel Drive  Subcompact Cars   Regular          13.733750        22
#
# ...

# %%
vehicles["Year"].unique()
# Out:
# array([1984, 1985, 1987, 1997, 1998, 1999, 1995, 1996, 2001, 2002, 2003,
#        2000, 2004, 2013, 2014, 2015, 2016, 2017, 1986, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012], dtype=int64)

# %%
import scipy
from scipy import stats

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
normal = norm()
norm.cdf(0)
# Out:
# 0.5

# %%
# The code below generates numbers between -1 and 1 in 0.1 increments
x = np.arange(-1, 1.1, 0.1)
# Now we will initialize the normal distribution object
normal = norm()
# Below we will use matplotlib to plot the bell curve. We will generate the probability density fuction
# (pdf) for the values we generated in x
plt.plot(x, norm.pdf(x))

# %%
np.linspace(1,10,5) #5 steps between 1 and 10
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
from scipy.linalg import solve

a = np.array([[5, 6], [2, 4]])
b = np.array([10, 8])
x = solve(a, b)
x
# Out:
# array([-1. ,  2.5])

# %%
from scipy.interpolate import interp1d

# We are creating a dataset where the x values are numbers 0 through 10 
# and the y values are the cosine of the x values
x = np.arange(0, 11, 0.1)
y = np.cos(x)

# We generate an interpolation function and then apply that function to the new data and plot
f = interp1d(x, y)
xnew = np.arange(0, 10.25, 0.25)
plt.plot(xnew, f(xnew))

# %%
f = interp1d(x, y)
xnew = np.arange(0, 5.25, 1)
plt.plot(xnew, f(xnew))
