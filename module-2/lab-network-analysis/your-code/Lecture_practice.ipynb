# %%
import networkx as nx
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import warnings
from custom import load_data as cf
import pandas as pd
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
G = cf.load_seventh_grader_network()

# %%
list(G.nodes(data=True))[0:5]
# Out:
# [(1, {'gender': 'male'}),
#  (2, {'gender': 'male'}),
#  (3, {'gender': 'male'}),
#  (4, {'gender': 'male'}),
#  (5, {'gender': 'male'})]

# %%
list(G.edges(data=True))[0:5]
# Out:
# [(1, 2, {'count': 1}),
#  (1, 3, {'count': 1}),
#  (1, 4, {'count': 2}),
#  (1, 5, {'count': 2}),
#  (1, 6, {'count': 3})]

# %%
len(G.nodes)
# Out:
# 29

# %%
len(G.edges)
# Out:
# 376

# %%
nx.draw(G, with_labels=True)

# %%
from nxviz import Arcviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-5c8bd5e63308> in <module>
# ----> 1 from nxviz import Arcviz
#
# ModuleNotFoundError: No module named 'nxviz'

# %%
list(G.neighbors(5))[:5]
# Out:
# [1, 2, 16, 17, 3]

# %%
hubs = {} 

for node in G.node: 
    hubs[node] = len(list(G.neighbors(node)))
    
hubs
# Out:
# {1: 14,
#  2: 15,
#  3: 17,
#  4: 23,
#  5: 27,
#  6: 27,
#  7: 12,
#  8: 14,
#  9: 16,
#  10: 12,
#  11: 14,
#  12: 10,
#  13: 13,
#  14: 8,
#  15: 9,
#  16: 5,
#  17: 6,
#  18: 1,
#  19: 6,
#  20: 13,
#  21: 15,
#  22: 19,
#  23: 12,
#  24: 16,
#  25: 11,
#  26: 16,
#  27: 15,
#  28: 5,
#  29: 5}
